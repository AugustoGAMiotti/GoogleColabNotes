# %% [markdown]
# <a href="https://colab.research.google.com/github/AugustoGAMiotti/GoogleColabNotes/blob/main/FGODataOld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pega URL de todas as páginas e joga em uma lista
#
# Processa duplicatas
#
# Pega as URLs individualmente e acessa
#
# Trata todas as tags. Se a skill já foi atualizada, utiliza a att, se não, salva a URL para usa-lá novamente.

# %%
import requests
import pandas as pd

url = 'https://fgo.gamepress.gg/servants'
response = requests.get(url, timeout=15)
r = requests.get('https://fgo.gamepress.gg/servants')
#Coletando o conteúdo
c = r.content
from bs4 import BeautifulSoup
#Criando Soup
soup = BeautifulSoup(c)
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
# <head>
# <meta charset="utf-8"/>
# <script>(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,"script","https://www.google-analytics.com/analytics.js","ga");ga("create", "UA-102267480-1", {"cookieDomain":"auto"});ga("set", "anonymizeIp", true);ga("set", "dimension1", "Nick Winters");ga("set", "dimension2", "Fate Grand Order Wiki - GamePress");ga("set", "dimension3", "1201");ga("set", "dimension4", "1");ga("set", "dimension5", "9");ga("send", "pageview");</script>
# <script>(function(h,o,t,j,a,r){
#   h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#   h._hjSettings={hjid:"1124514",hjsv:6};
#   a=o.getElementsByTagName('head')[0];
#   r=o.createElement('script');r.async=1;
#   r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#   a.appendChild(r);
# })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');</script>
# <meta content="Servants | Fate Grand Order Wiki - GamePress" name="title"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Fate Grand Order GamePress" property="og:site_name"/>
# <meta content="Servants" name="twitter:title"/>
# <meta content="Here's the full FGO Servant List!" name="twitter:description"/>
# <meta content="Here's the full FGO Servant List!" name="description"/>
# <meta content="https://fgo.gamepress.gg/servants" property="og:url"/>
# <meta content="Fate Grand Order Wiki, Database, News, and Community for the Fate Grand Order Player!" name="abstract"/>
# <meta content="Servants" property="og:title"/>
# <meta content="https://fgo.gamepress.gg/servants" name="twitter:url"/>
# <meta content="Fate Grand Order Wiki, Database, News, and Community for the Fate Grand Order Player!" property="og:description"/>
# <meta content="https://fgo.gamepress.gg/sites/default/files/2018-10/Servants2.png" name="twitter:image"/>
# <meta content="https://fgo.gamepress.gg/sites/default/files/2018-10/Servants2.png" property="og:image"/>
# <meta content="https://gamepress.gg/gamepress.jpg" property="og:image"/>
# <meta content="Drupal 8 (https://www.drupal.org)" name="Generator"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/sites/default/files/fgo-favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="https://fgo.gamepress.gg/servants" rel="canonical"/>
# <link href="https://fgo.gamepress.gg/node/1201" rel="shortlink"/>
# <link href="https://fgo.gamepress.gg/servants" rel="revision"/>
# <title>Servants | Fate Grand Order Wiki - GamePress</title>
# <link href="/core/assets/vendor/normalize-css/normalize.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/misc/normalize-fixes.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/node/node.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/ajax-progress.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/align.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/autocomplete-loading.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/fieldgroup.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/container-inline.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/clearfix.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/details.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/hidden.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/item-list.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/js.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/nowrap.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/position-container.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/progress.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/reset-appearance.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/resize.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/sticky-header.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/system-status-counter.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/system-status-report-counters.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/system-status-report-general-info.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/tabledrag.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/tablesort.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/system/components/tree-child.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/stable/css/views/views.module.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/assets/vendor/jquery.ui/themes/base/core.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/assets/vendor/jquery.ui/themes/base/menu.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/assets/vendor/jquery.ui/themes/base/autocomplete.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/modules/paragraphs/css/paragraphs.unpublished.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/assets/vendor/jquery.ui/themes/base/theme.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/modules/search_api_autocomplete/css/search_api_autocomplete.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/themes/main/css/slick.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/themes/main/css/slick-theme.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/themes/main/css/awesomplete.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/themes/main/css/main.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/themes/gamepressbase/css/gamepressbase.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/action-links.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/breadcrumb.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/button.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/collapse-processed.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/container-inline.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/details.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/exposed-filters.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/field.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/form.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/icons.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/inline-form.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/item-list.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/link.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/links.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/menu.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/more-link.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/pager.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tabledrag.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tableselect.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tablesort.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/tabs.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/textarea.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/ui-dialog.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/messages.css?sfz19e" media="all" rel="stylesheet"/>
# <link href="/core/themes/classy/css/components/progress.css?sfz19e" media="all" rel="stylesheet"/>
# <!--[if lte IE 8]>
# <script src="/sites/default/files/js/js_VtafjXmRvoUgAzqzYTA3Wrjkx9wcWhjP0G4ZnnqRamA.js"></script>
# <![endif]-->
# <script src="/core/assets/vendor/modernizr/modernizr.min.js?v=3.3.1"></script>
# <script src="/sites/default/files/js/js_IfqzHiUTwZH2H0gSZOmiplXoH34uGUxDaNEYeime-xM.js"></script>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css" integrity="sha384-T8Gy5hrqNKT+hzMclPo118YTQO6cYprQmhrYwIiQ/3axmI1hQomh7Ud2hPOy8SP1" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Noto+Sans:400,400i,700,700i" rel="stylesheet"/>
# <script src="https://comment.gamepress.gg/js/count.js?ver4"></script>
# </head>
# <body class="one-sidebar sidebar-second site-gamepress path-node node--type-page">
# <div id="top-page"></div>
# <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas="">
# <div id="div-ad-Gamepress_Desktop_Skin_1x1">
# <script>
#   if(detectWidth() >= 1680) { googletag.cmd.push(function() { googletag.display('div-ad-Gamepress_Desktop_Skin_1x1'); }); }
#   </script>
# </div>
# <div id="overlay" onclick="closeNav()"></div>
# <script type="text/javascript">
#   (function () {
#   window.aax = window.aax || {}; window.aax.initTime = new Date().getTime(); window.aax.deliverExchangeDemand = function () { };
#   window.aax.pubId = 'AAXDDFXYK';
#   window.aax.ver = 1.2;
#   window.aax.hst = window.location.hostname;
#   var aaxEndpoint = '//c.aaxads.com/aax.js?pub=' + window.aax.pubId + '&hst=' + window.aax.hst + '&ver=' + window.aax.ver;
#   function isSSL() {
#   return ('https:' == document.location.protocol);
#   }
#   function getProtocol() {
#   return isSSL() ? 'https:' : 'http:'
#   }
#   function writeSource(endpoint) {
#   var source = getProtocol() + endpoint;
#   document.write('<scr' + 'ipt type="text/javascript" src="' + source + '"></scr' + 'ipt>');
#   }
#   writeSource(aaxEndpoint);
#   })();
#   </script>
# <script type="text/javascript">
# /* A9 Load Lib */
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function()
# {q("f",arguments)},setDisplayBids:function(){},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(
# A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
# </script>
# <script type="text/javascript">
#     var adsStart = (new Date()).getTime();
#     function detectWidth() {
#         return window.screen.width || window.innerWidth || window.document.documentElement.clientWidth || Math.min(window.innerWidth, window.document.documentElement.clientWidth) || window.innerWidth || window.document.documentElement.clientWidth || window.document.getElementsByTagName('body')[0].clientWidth;
#     }
#
#     var TIMEOUT = 2000;
#
#     /* A9 Init */
#     apstag.init({
#         pubID: 'edf9e12e-6c41-40a2-bcc3-2f7942aec18a',
#         adServer: 'googletag'
#     });
#
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#     var adUnits = adUnits || [];
#     /* A9 Vars */
#     var a9Slots = [];
#     var a9BidsBack = false;
#
#     function initAdServer() {
#         if (pbjs.initAdserverSet) return;
#         (function() {
#             var gads = document.createElement('script');
#             gads.async = true;
#             gads.type = 'text/javascript';
#             var useSSL = 'https:' == document.location.protocol;
#             gads.src = (useSSL ? 'https:' : 'http:') +
#                 '//www.googletagservices.com/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#         pbjs.initAdserverSet = true;
#     };
#     pbjs.timeout = setTimeout(initAdServer, TIMEOUT);
#     pbjs.timeStart = adsStart;
#
#     var dfpNetwork = '31904509';
#
#     // START: Defining Adunits
#     if(detectWidth() > 980)
#     {
#         // Desktop Adunits
#         adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Desktop_728x90_ATF',
#                 size: [[728, 90]],
#                 code: 'div-ad-GrandOrder_Desktop_728x90_ATF',
#                 assignToVariableName: false // false if not in use
#             });
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Desktop_728x90_BTF',
#                 size: [[728, 90],[970,90],[970,250]],
#                 code: 'div-ad-GrandOrder_Desktop_728x90_BTF',
#                 assignToVariableName: false // false if not in use
#             });
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Desktop_RR_300x250_A',
#                 size: [[300, 250]],
#                 code: 'div-ad-GrandOrder_Desktop_RR_300x250_A',
#                 assignToVariableName: false // false if not in use
#             });
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Desktop_RR_300x250_B',
#                 size: [[300, 250],[300, 600]],
#                 code: 'div-ad-GrandOrder_Desktop_RR_300x250_B',
#                 assignToVariableName: false // false if not in use
#             });
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Desktop_RR_300x250_C',
#                 size: [[300, 250],[300, 600]],
#                 code: 'div-ad-GrandOrder_Desktop_RR_300x250_C',
#                 assignToVariableName: false // false if not in use
#             });
#
#                     console.log("NOT FRONT PAGE or no news module");
#                                                                     adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Desktop_728x90_Extra_1',
#                 size: [[728, 90]],
#                 code: 'div-ad-GrandOrder_Desktop_728x90_Extra_1',
#                 assignToVariableName: false // false if not in use
#             });
#                                                                                                                               adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Desktop_728x90_Extra_2',
#                 size: [[728, 90]],
#                 code: 'div-ad-GrandOrder_Desktop_728x90_Extra_2',
#                 assignToVariableName: false // false if not in use
#             });    } else {
#         // Mobile Adunits
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Mobile_300x250_Extra_3',
#                 size: [[300, 250]],
#                 code: 'div-ad-GrandOrder_Mobile_300x250_Extra_3',
#                 assignToVariableName: false // false if not in use
#             });
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Mobile_300x250_Extra_4',
#                 size: [[300, 250]],
#                 code: 'div-ad-GrandOrder_Mobile_300x250_Extra_4',
#                 assignToVariableName: false // false if not in use
#             });
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Mobile_320x50_Top',
#                 size: [[320, 50]],
#                 code: 'div-ad-GrandOrder_Mobile_320x50_Top',
#                 assignToVariableName: false // false if not in use
#             });
#                 adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Mobile_320x50_Floating',
#                 size: [[320, 50]],
#                 code: 'div-ad-GrandOrder_Mobile_320x50_Floating',
#                 assignToVariableName: false // false if not in use
#             });
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Mobile_300x250_BTF_1',
#                 size: [[300, 250]],
#                 code: 'div-ad-GrandOrder_Mobile_300x250_BTF_1',
#                 assignToVariableName: false // false if not in use
#             });
#                                                                                                                                                           adUnits.push({
#                 network: dfpNetwork,
#                 adunit: 'GrandOrder_Mobile_300x250_BTF_2',
#                 size: [[300, 250]],
#                 code: 'div-ad-GrandOrder_Mobile_300x250_BTF_2',
#                 assignToVariableName: false // false if not in use
#             });
#
#     }
#     // END: Defining Adunits
#
#     googletag.cmd.push(function() {
#       if(adUnits){
#         var dfpSlots = [];
#         for (var i = 0, len = adUnits.length; i < len; i++) {
#           dfpSlots[i] = googletag.defineSlot('/'+adUnits[i].network+'/'+adUnits[i].adunit, adUnits[i].size, adUnits[i].code).addService(googletag.pubads());
#           if(adUnits[i].assignToVariableName && (adUnits[i].assignToVariableName !== null)) window[adUnits[i].assignToVariableName] = dfpSlots[i];
#         }
#       }
#     });
#
#     /* A9 Slots */
#     if(adUnits){
#         if(apstag){
#           for (var i = 0, len = adUnits.length; i < len; i++) {
#                   a9Slots.push({slotID: adUnits[i].code,slotName: adUnits[i].network+'/'+adUnits[i].adunit,sizes: adUnits[i].size});
#               }
#         }
#     }
#     /* A9 Request Bids */
#     apstag.fetchBids({
#                         slots: a9Slots,
#                         timeout: TIMEOUT
#                     },
#                     function(bids) {
#                         console.log('BDS back',(new Date()).getTime()-adsStart,bids);
#                         a9BidsBack = true;
#                     });
#
#     googletag.cmd.push(function() {
#         /* A9 Set Bids */
#         if(a9BidsBack) apstag.setDisplayBids();
#         // Header Bidding Targeting
#         pbjs.que.push(function() {pbjs.setTargetingForGPTAsync();});
#
#         if(detectWidth() >= 2200) { googletag.defineSlot('/31904509/Gamepress_Desktop_Skin_1x1', [1, 1], 'div-ad-Gamepress_Desktop_Skin_1x1').addService(googletag.pubads()); }
#
#         // Init DFP
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#         googletag.enableServices();
#     });
# </script>
# <script async="true" src="https://gamepress.gg/prebid/prebidglobal.js?1-30-23" type="text/javascript"></script>
# <div style="background-color: #22c55e; padding: 10px;">
# <div class="outer-wrapper" style="display: flex; justify-content: space-between; align-items: center;">
# <div style="color: #fff; flex-grow: 1;">Check out the new Fate/Grand Order v2 site beta!</div>
# <a href="https://grandorder.gamepress.gg" style="flex: none; border-radius: 999px; color: #ffffff; background-color: #16a34a; padding: 5px 15px; font-size: 14px; font-weight: bold;">Go to V2 Site</a>
# </div>
# </div>
# <div id="menu-close" onclick="closeNav()"><i aria-hidden="true" class="fa fa-times"></i></div>
# <div id="sidenav">
# <div class="sidemenu-icon"><img src="/GamePressNewLogo.png"/></div>
# <div class="menu-c-container">
# <ul class="menu">
# <li class="menu-item menu-item--expanded">
# <span>Featured</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/606281" href="/guide-list">Guides Database</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/51981" href="/event-guides" title="Event Guides">Event Guides</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/372871" href="/reroll-guide">Reroll Guide</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/532941" href="/rabbits-reviews-archive">Rabbit's Reviews Archive</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/532936" href="/rathilals-mmms-archive">Rathilal's MMMs Archive</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Rankings</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/364071" href="/servant-tier-list">5 Star Tier List</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/364076" href="/4-star-tier-list">4 Star Tier List</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/364081" href="/1-3-star-tier-list" title="1-3 Star Tier List">1-3 Star Tier List</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/376041" href="/reroll-tier-list">Reroll Tier List</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded menu-item--active-trail">
# <span>Servants</span>
# <ul class="menu">
# <li class="menu-item menu-item--active-trail">
# <a class="is-active" data-drupal-link-system-path="node/1201" href="/servants" title="All Servants">All Servants</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/6036" href="/servant-stats" title="Servant Stats">Servant Stats</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/380591" href="/servant-availability">Servant Availability</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/338901" href="/servant-alignments" title="Servants listed by Alignment">Servant Alignments</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/409431" href="/servants-instant-death-rate">Servants by Instant Death Rate</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Gameplay</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/444021" href="/noble-phantasm-list">Noble Phantasms</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/1711" href="/materials" title="Ascension And Skill Up Materials">Ascension Materials</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/4871" href="/craft-essences" title="Craft Essences">Craft Essences</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/30876" href="/mystic-code" title="Mystic Codes List">Mystic Codes</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/823611" href="/command-code-list">Command Code List</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/30721" href="/all-interludes-and-rank-quest-release-dates">All Interlude/Rank Up Quests</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/267801" href="/bond-points-and-bond-experience-farming">Bond Point Farming</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/876606" href="/summon-banner-list">Summon Banner List</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Tools</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/8911" href="/servant-planner-old">Servant Planner</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/4441" href="/summon-simulator" title="Summon Simulator">Summon Simulator</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/5501" href="/friend-points-summon-simulator" title="Friend Points Summon Simulator">FP Summon Simulator</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/372606" href="/command-chain-calculator">Command Chain Calculator</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/370076" href="/jp-np-refund-calculator" title="Ranks all Servants by amount of NP Gauge % refunded by their NP">NP Refund Calculator</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/7501" href="/strongest-np-against-sabers" title="Strongest NP in Fate/Grand Order">Strongest NP</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/6026" href="/exp-calculator" title="EXP Calculator">EXP Calculator</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/868476" href="/support-servant-skill-combo-finder">Support Servant Skill Combo Finder</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/868336" href="/craft-essence-effect-combo-finder">Craft Essence Effect Combo Finder</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Singularities/Main Quests</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/104781" href="/singularity-camelot">Camelot</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/255496" href="/singularity-babylonia">Babylonia</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/272386" href="/singularity-solomon">Solomon</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/338651" href="/pseudo-singularity-i-quarantined-territory-malice-shinjuku-shinjuku-phantom-incident">Shinjuku</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/447906" href="/pseudo-singularity-ii-subterranean-world-folklore-agartha-women-agartha">Agartha</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/596961" href="/pseudo-singularity-iii-stage-carnage-shimousa-seven-duels-swordmasters">Shimousa</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/633891" href="/pseudo-singularity-iv-forbidden-advent-garden-salem-heretical-salem">Salem</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/762181" href="/lostbelt-no-1-permafrost-empire-anastasia-grand-duchess-beast-nation">Lostbelt 1: Anastasia</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/818786" href="/lostbelt-no2-eternal-icy-fire-century-gotterdammerung-good-fellow-everlasting-flame">Lostbelt 2: Götterdämmerung</a>
# </li>
# <li class="menu-item">
# <a href="https://gamepress.gg/grandorder/lostbelt-no3-synchronized-intellect-nation-sin-crimson-beauty-under-moon">Lostbelt 3: SIN</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/957906" href="/lostbelt-no4-samsara-genesis-and-terminus-yugakshetra-final-dark-god">Lostbelt 4: Yuga Kurukshetra</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/1012971" href="/lostbelt-no5-ancient-ocean-dreadnought-gods-atlantis-day-bring-down-gods">Lostbelt 5.1: Atlantis</a>
# </li>
# <li class="menu-item">
# <a href="https://gamepress.gg/grandorder/lostbelt-no52-interstellar-mountainous-city-olympus-day-bring-down-gods">Lostbelt 5.2: Olympus</a>
# </li>
# <li class="menu-item">
# <a href="https://gamepress.gg/grandorder/lostbelt-no55-naraka-mandala-heian-kyo-thunderous-flash">Lostbelt 5.5: Heian-kyo</a>
# </li>
# <li class="menu-item">
# <a href="https://gamepress.gg/grandorder/lostbelt-no6-act-i-fae-round-table-domain-avalon-le-fae-moment-planet-born">Lostbelt 6: Avalon (Part 1)</a>
# </li>
# <li class="menu-item">
# <a href="https://gamepress.gg/grandorder/lostbelt-no6-act-ii-fae-round-table-domain-avalon-le-fae-moment-planet-born">Lostbelt 6: Avalon (Part 2)</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Quests</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/4876" href="/daily-quests" title="Daily Quests">Daily Quests</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/4881" href="/event-quests" title="Event Quests">Event Quests</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/4886" href="/free-quests" title="Free Quests">Free Quests</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/4891" href="/interlude-quests" title="Interlude / Rank Up Quests">Interlude Quests</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/4896" href="/main-quests" title="Main Quests">Main Quests</a>
# </li>
# <li class="menu-item">
# <a href="https://gamepress.gg/grandorder/advanced-quests">Advanced Quests</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Manga</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/8161" href="/manga/chapter-1-1" title="Even More Learning with Manga! FGO by Riyo">Even More Learning with Manga!</a>
# </li>
# <li class="menu-item">
# <a href="http://fate-go.us/gudao/" title="Fate/GUDAGUDA Order">Fate/GUDAGUDA Order</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/8046" href="/manga/chapter-0" title="Learning with Manga! FGO by Riyo">Learning with Manga!</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/7966" href="/manga/chapter-1" title="More Learning with Manga! FGO by Riyo">More Learning with Manga!</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Other</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/7386" href="/experience-table" title="Fate/Grand Order Experience Table">Experience Table</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/384856" href="/fgo-us-tour-kickoff-introduction">FGO USA Tour</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/1611" href="/enemies" title="Enemies">Enemies</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>Skills</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/1716" href="/class-skills" title="Class Skills">Class Skills</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/1351" href="/servant-skills" title="Servant Skills">Servant Skills</a>
# </li>
# <li class="menu-item">
# <a data-drupal-link-system-path="node/988076" href="/append-skill-list">Append Skills</a>
# </li>
# <li class="menu-item">
# <a href="https://grandorder.gamepress.gg/tags">Servant Tags</a>
# </li>
# </ul>
# </li>
# <li class="menu-item menu-item--expanded">
# <span>About</span>
# <ul class="menu">
# <li class="menu-item">
# <a data-drupal-link-system-path="node/604011" href="/fategrand-order-gamepress-community-discord">Contact Us: Community / Discord Links</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="page" role="document">
# <header class="gamepress-top-menu">
# <div class="gamepress-top-container">
# <div class="outer-wrapper">
# <div id="site-header">
# <div class="top-logo-container">
# <a class="logo-name-container" href="/" rel="home" title="Home">
# <img alt="Home" class="site-logo" src="/sites/default/files/fgo-icon.jpg" style="border-radius: 999px;"/>
# <div class="site-name">Fate Grand Order Wiki - GamePress</div>
# </a>
# </div>
# <div class="top-search-menu">
# <div class="block block-views block-views-exposed-filter-blocksite-search-page-1">
# <h2>Search</h2>
# <form accept-charset="UTF-8" action="/search" class="views-exposed-form" data-drupal-selector="views-exposed-form-site-search-page-1" id="views-exposed-form-site-search-page-1" method="get">
# <div class="form--inline clearfix">
# <div class="js-form-item form-item js-form-type-search-api-autocomplete form-type-search-api-autocomplete js-form-item-query form-item-query form-no-label">
# <input class="form-autocomplete form-text" data-autocomplete-path="/search_api_autocomplete/site_search?display=page_1&amp;&amp;filter=query" data-drupal-selector="edit-query" data-search-api-autocomplete-search="site_search" id="edit-query" maxlength="128" name="query" placeholder="Search..." size="30" type="text" value=""/>
# </div>
# <div class="form-actions js-form-wrapper form-wrapper" data-drupal-selector="edit-actions" id="edit-actions"><input class="button js-form-submit form-submit" data-drupal-selector="edit-submit-site-search" id="edit-submit-site-search" type="submit" value="Apply"/>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="menu-container">
# <div class="menu--top-menu outer-wrapper">
# <div id="side-menu-button" onclick="openNav()"><div class="menu-bars"><i aria-hidden="true" class="fa fa-bars"></i></div><div class="menu-label">Menu</div></div>
# <div class="top-menu"><ul>
# <li>
# <a href="/servant-tier-list" style="background-image: url(
#
#
#
#             /sites/default/files/2019-03/trophy.png
#
#
#   )">Tier List</a>
# </li>
# <li>
# <a href="/servants" style="background-image: url(
#
#             /sites/default/files/2019-11/05_Craft%20Essence_0.png
#
#   )">Servants</a>
# </li>
# <li>
# <a href="/servant-planner" style="background-image: url(
#
#
#
#             /sites/default/files/2019-11/08_QP%20-%20Quantum%20Pieces_0.png
#
#
#   )">Planner</a>
# </li>
# <li>
# <a href="https://grandorder.gamepress.gg/summon-simulator" style="background-image: url(
#
#             /sites/default/files/2019-11/01_Saint%20Quartz_0.png
#
#   )">Simulator</a>
# </li>
# <li>
# <a href="/guide-list" style="background-image: url(
#
#             /sites/default/files/2019-11/09_Bond%20Points_0.png
#
#   )">Guides</a>
# </li>
# <li>
# <a href="/materials" style="background-image: url(
#
#             /sites/default/files/2019-11/06_Holy%20Grail_0.png
#
#   )">Materials</a>
# </li>
# </ul></div>
# </div>
# </div>
# <div id="top-page-button">
# <i aria-hidden="true" class="fa fa-arrow-up"></i>
# <div class="top-label">Top</div>
# </div>
# <div class="top-mobile-ad">
# <div class="hide-desktop"><center style="margin-bottom: 5px; color: #6b6b6b;"><small>Advertisement</small></center></div>
# <div id="div-ad-GrandOrder_Mobile_320x50_Top">
# <script>
# if(detectWidth() <= 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Mobile_320x50_Top'); }); }
# </script>
# </div>
# </div>
# </header></div>
# <div id="bottom-sticky-ad">
# <div id="div-ad-GrandOrder_Mobile_320x50_Floating">
# <script>
# if(detectWidth() <= 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Mobile_320x50_Floating'); }); }
# </script>
# </div>
# </div>
# <script>
#
# function decodeHtml(html) {
#     var txt = document.createElement("textarea");
#     txt.innerHTML = html;
#     return txt.value;
# }
#
# function getPathByValue(value){
#     for(var i = 0; i < list.length; i++){
#         if(list[i].toLowerCase() == value.toLowerCase()){
#             return paths[i];
#         }
#     }
# }
# /* Set the width of the side navigation to 250px */
#
# function openNav() {
#   var $slider = document.getElementById('sidenav');
#   $slider.setAttribute("class", "slide-in");
#   document.getElementById("overlay").style.display = "block";
#   document.getElementById("menu-close").style.display = "block";
#   document.getElementById("bottom-sticky-ad").style.display = "none";
#   document.body.style.overflow = "hidden";
# }
#
# function closeNav() {
#   var $slider = document.getElementById('sidenav');
#   $slider.setAttribute("class", "slide-out");
#   document.getElementById("overlay").style.display = "none";
#   document.getElementById("menu-close").style.display = "none";
#   document.getElementById("bottom-sticky-ad").style.display = "block";
#   document.body.style.overflow = "auto";
# }
#
# </script>
# <main class="outer-wrapper" role="main">
# <section class="column-2-setup" id="content">
# <div id="content-inner">
# <div id="gamepress-top-content">
# <div class="top-content-brand">GamePress</div>
# <div class="top-ad-desktop">
# <div id="div-ad-GrandOrder_Desktop_728x90_ATF">
# <script>
# if(detectWidth() > 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Desktop_728x90_ATF'); }); }
# </script>
# </div>
# <style>
# .prom {
# margin-bottom:10px;
#     display: none;
#   }
#   body.mobile.android .prom-unit-android {
#     display: block;
#   }
#   body.mobile.iphone .prom-unit-ios {
#     display: block;
#   }
#   body.mobile.ipad  .prom-unit-ios {
#     display: block;
#   }
#
#   body.desktop .prom-unit-desktop {
#     display: block;
#   }
# </style>
# </div>
# <div id="page-title">
# <h1>Servants</h1>
# <div class="title-sub">
# <div class="last-updated-date">
# <time datetime="2023-12-06T14:03:47">Last Updated: December 6, 2023 | </time>
# </div>
# <a href="https://gamepress.atlassian.net/servicedesk/customer/portals" target="_blank">Submit Feedback or Error</a>
# </div>
# </div>
# </div>
# <div class="">
# <div class="hidden" data-drupal-messages-fallback=""></div>
# <div class="block block-system block-system-main-block" id="block-gamepressbase-content">
# <article about="/servants" class="" data-history-node-id="1201" id="node-1201" role="article" typeof="schema:WebPage">
# <div class="page-top-content">
# </div>
# <div class="field field--name-field-page-content field--type-entity-reference-revisions field--label-hidden field__items">
# <div class="field__item"> <div class="paragraph paragraph--type--embedded-node paragraph--view-mode--default">
# <div class="field field--name-field-node-to-embed field--type-entity-reference field--label-hidden field__item"><article about="/node/737701" class="" data-history-node-id="737701" id="node-737701" role="article">
# <div class="field field--name-field-content-to-embed field--type-entity-reference-revisions field--label-hidden field__items">
# <div class="field__item"> <div class="paragraph paragraph--type--featured-content paragraph--view-mode--default">
# <div class="featured-2-columns-desktop featured-2-columns-mobile">
# <div class="content-2-group-item current-page">
# <a href="/servants" hreflang="en"><img alt="Servants" class="image-style-_00x315" height="315" src="/sites/default/files/styles/600x315/public/2018-10/Servants2.png?itok=GQtxAgnY" typeof="foaf:Image" width="600"/>
# </a>
# <a class="featured-content-title" href="/servants"><span class="field field--name-title field--type-string field--label-hidden" property="schema:name">Servants</span>
# </a>
# </div>
# <div class="content-2-group-item">
# <a href="/servant-stats" hreflang="en"><img alt="Servant Stats" class="image-style-_00x315" height="315" src="/sites/default/files/styles/600x315/public/2018-10/Servants-Stats2.png?itok=ID84wwLf" typeof="foaf:Image" width="600"/>
# </a>
# <a class="featured-content-title" href="/servant-stats"><span class="field field--name-title field--type-string field--label-hidden" property="schema:name">Servant Stats</span>
# </a>
# </div>
# <div class="content-2-group-item">
# <a href="/servant-availability" hreflang="en"><img alt="Servant Availability" class="image-style-_00x315" height="315" src="/sites/default/files/styles/600x315/public/2019-04/Servant-Availability.png?itok=WinX-3ix" typeof="foaf:Image" width="600"/>
# </a>
# <a class="featured-content-title" href="/servant-availability"><span class="field field--name-title field--type-string field--label-hidden" property="schema:name">Servant Availability</span>
# </a>
# </div>
# <div class="content-2-group-item">
# <a href="/servant-alignments" hreflang="en"><img alt="Alignment Chart Banner" class="image-style-_00x315" height="315" src="/sites/default/files/styles/600x315/public/2019-02/Servants-by-Alignment.png?itok=q1sPNK8i" typeof="foaf:Image" width="600"/>
# </a>
# <a class="featured-content-title" href="/servant-alignments"><span class="field field--name-title field--type-string field--label-hidden" property="schema:name">Servant Alignments</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="field__item"> <div class="paragraph paragraph--type--featured-content-list paragraph--view-mode--default">
# <div class="field field--name-field-featured-content-list">
# <a href="https://fgo.gamepress.gg//summon-banner-list"><div class="field__item"><div class="featured-content-list-main">
# <div class="featured-list-image">
# <div class="field field--name-field-og-image field--type-image field--label-hidden field__item"> <img alt="Summon Banner List" class="image-style-featured-content-list" height="50" src="/sites/default/files/styles/featured_content_list/public/2020-09/FGO%20Center%20Banner%20Summon%20Banner%20List.png?itok=3mypFi7A" typeof="foaf:Image" width="100"/>
# </div>
# </div>
# <div class="featured-list-link">Summon Banner List</div>
# </div>
# </div></a>
# </div>
# </div>
# </div>
# </div>
# </article></div>
# </div>
# </div>
# <div class="field__item">
# <div class="ad-container">
# <div class="desktop-ad">
# <center>
# <div id="div-ad-GrandOrder_Desktop_728x90_Extra_1">
# <script>
# if(detectWidth() > 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Desktop_728x90_Extra_1'); }); }
# </script>
# </div>
# </center>
# </div>
# </div>
# <div class="ad-container">
# <div class="mobile-ad">
# <center>
# <div id="div-ad-GrandOrder_Mobile_300x250_BTF_1">
# <script>
# if(detectWidth() <= 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Mobile_300x250_BTF_1'); }); }
# </script>
# </div>
# </center>
# </div>
# <script language="javascript" src="https://live.primis.tech/live/liveView.php?s=102483" type="text/javascript"></script>
# </div>
# </div>
# <div class="field__item"> <span id=""></span>
# <h2 class="main-title">
# Servant List
# </h2>
# </div>
# <div class="field__item"><span id="topic-1577191">
# <div id="filters"></div><div class="topic-text"> <div class="paragraph paragraph--type--text paragraph--view-mode--default">
# <div class="clearfix text-formatted field field--name-field-text field--type-text-long field--label-hidden field__item"><div class="servants-list-filters">
# <h3 class="sub-title">Filter Class</h3>
# <div class="tier-filter-table filter-columns-8 filters-Class clearfix">
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="81" id="filter-class-saber">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GraySabericon.png?itok=0EI07tNY"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="86" id="filter-class-archer">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayArchericon.png?itok=5fyN9D3d"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="91" id="filter-class-lancer">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayLancericon.png?itok=Ls-5Tyi5"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="96" id="filter-class-rider">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayRidericon.png?itok=IgzPTCbm"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="101" id="filter-class-caster">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayCastericon.png?itok=scXal-e1"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="106" id="filter-class-assassin">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayAssassinicon.png?itok=yvw9dS_w"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="111" id="filter-class-berserker">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayBerserkericon.png?itok=SSlJidMj"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="76" id="filter-class-shielder">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayShieldericon.png?itok=dCfX-2dF"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="116" id="filter-class-ruler">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayRulericon.png?itok=KpjO5eT2"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="126" id="filter-class-avenger">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayAvengericon.png?itok=AvQKFYbT"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="2881" id="filter-class-alter ego">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayAlteregoicon.png?itok=ZUbIcv7E"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="3171" id="filter-class-moon cancer">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayMooncancericon.png?itok=BgBbP0Io"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="3166" id="filter-class-foreigner">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2019-05/GrayForeignericon.png?itok=WXJVQuuM"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="9566" id="filter-class-pretender">
# <img src="https://fgo.gamepress.gg/grandorder/sites/grandorder/files/styles/thumbnail/public/2021-08/Pretender_Silver_1.png?itok=QLP2WA2U"/></div>
# <div class="filter-inactive tier-filter" data-catid="1" data-tid="10586" id="filter-class-beast">
# <img src="https://gamepress.gg/grandorder/sites/grandorder/files/2023-04/class2_33.png"/></div>
# </div>
# <h3 class="sub-title">Filter Release Status</h3>
# ...
# </div>
# <div class="featured-list-link">
# Hunting Quest Part 12
# </div>
# </div>
# </div>
# </a></span></div></div>
# <div class="views-row"><div class="views-field views-field-view-node"><span class="field-content"><a href="/app-release-anniversary-2024-limited-login-bonus">
# <div class="field__item">
# <div class="featured-content-list-main">
# <div class="featured-list-image">
# <img alt="App Release Anniversary 2024 Limited Login Bonus" class="image-style-featured-content-list" height="50" src="/sites/default/files/styles/featured_content_list/public/2024-06/20240625%20App%20Release%20Anniv%20Res.png?itok=WRofyE-v" typeof="Image" width="100"/>
# </div>
# <div class="featured-list-link">
# App Release Anniversary 2024 Limited Login Bonus
# </div>
# </div>
# </div>
# </a></span></div></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hide-desktop">
# <div class="bottom-ads-mobile-1"><div class="mobile-ad">
# <div id="div-ad-GrandOrder_Mobile_300x250_Extra_3">
# <script>
# if(detectWidth() <= 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Mobile_300x250_Extra_3'); }); }
# </script>
# </div>
# </div>
# </div>
# </div>
# </section>
# <aside class="sidebar" id="sidebar-second" role="complementary">
# <div class="sidebar-1-ad-desktop">
# <div id="div-ad-GrandOrder_Desktop_RR_300x250_A" style="margin:10px 0px;">
# <script>
# if(detectWidth() > 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Desktop_RR_300x250_A'); }); }
# </script>
# </div></div>
# <div class="views-element-container" id="block-views-block-popular-pages-block-1">
# <div class="popular-pages-block popular-block">
# <h2>Popular Pages Today</h2>
# <ul>
# <li>
# <a href="/servant-tier-list">
# <span class="pages-ranking-number ranking-number-1">1</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2021-01/FGO-Servant-Tier-List.png?itok=nMK6fW4u"/>
# </span>
# <span class="pages-ranking-title">
# Servant Tier List
# </span>
# </a>
# </li>
# <li>
# <a href="/servants">
# <span class="pages-ranking-number ranking-number-2">2</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2018-10/Servants2.png?itok=R7sC0k_k"/>
# </span>
# <span class="pages-ranking-title">
# Servants
# </span>
# </a>
# </li>
# <li>
# <a href="/fategrand-order-2023-6th-anniversary">
# <span class="pages-ranking-number ranking-number-3">3</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2023-07/20230703%206th%20Anniv%20Main%20Res.png?itok=Q7G1MBsA"/>
# </span>
# <span class="pages-ranking-title">
# Fate/Grand Order 2023 - 6th Anniversary
# </span>
# </a>
# </li>
# <li>
# <a href="/buster-looping-tier-list">
# <span class="pages-ranking-number ranking-number-4">4</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2023-06/FGO%20Banner%20Buster%20Looping%20Tier%20List.png?itok=xWvUV5Wq"/>
# </span>
# <span class="pages-ranking-title">
# Buster Looping Tier List
# </span>
# </a>
# </li>
# <li>
# <a href="/lostbelt-no6-avalon-le-fae-part-2-spoiler-free-walkthrough">
# <span class="pages-ranking-number ranking-number-5">5</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2023-06/Lostbelt6p2%20Banners%20Walkthrough.png?itok=lqzGP4_y"/>
# </span>
# <span class="pages-ranking-title">
# Lostbelt No.6: Avalon le Fae (Part 2) Spoiler...
# </span>
# </a>
# </li>
# <li>
# <a href="/fategrand-order-2023-6th-anniversary-commemorative-campaign">
# <span class="pages-ranking-number ranking-number-6">6</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2023-06/20230628%206th%20Commem%20Camp%20Res_0.png?itok=VIkhR3ya"/>
# </span>
# <span class="pages-ranking-title">
# "Fate/Grand Order 2023 - 6th Anniversary" Com...
# </span>
# </a>
# </li>
# <li>
# <a href="/summon-simulator">
# <span class="pages-ranking-number ranking-number-7">7</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2023-07/20230703%206th%20Anniv%20Koya%20Light%20Pickup%20Res.png?itok=QnodX4uG"/>
# </span>
# <span class="pages-ranking-title">
# Summon Simulator
# </span>
# </a>
# </li>
# <li>
# <a href="/servant-rank-quests-part-14">
# <span class="pages-ranking-number ranking-number-8">8</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2023-07/20230703%20Rank%20Up%2014.png?itok=Bzdo4qgd"/>
# </span>
# <span class="pages-ranking-title">
# Servant Rank Up Quests Part 14
# </span>
# </a>
# </li>
# <li>
# <a href="/summon-banner-list">
# <span class="pages-ranking-number ranking-number-9">9</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2020-09/FGO%20Center%20Banner%20Summon%20Banner%20List.png?itok=rxEDc-MH"/>
# </span>
# <span class="pages-ranking-title">
# Summon Banner List
# </span>
# </a>
# </li>
# <li>
# <a href="/materials">
# <span class="pages-ranking-number ranking-number-10">10</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/80x40/public/2018-10/Materials2.png?itok=cwL9lO8r"/>
# </span>
# <span class="pages-ranking-title">
# Materials
# </span>
# </a>
# </li>
# </ul>
# <div> <div class="view view-popular-pages view-id-popular_pages view-display-id-block_1 js-view-dom-id-101474ec50064e06b11ea8b53422c13522a40dff1ba6a6c3fe4de5ae780f8494">
# <div class="view-content">
# </div>
# <div class="view-footer">
# <a href="https://fgo.gamepress.gg/popular-all">See All </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hide-desktop">
# <div class="bottom-ads-mobile-2"><div class="mobile-ad">
# <div id="div-ad-GrandOrder_Mobile_300x250_Extra_4">
# <script>
# if(detectWidth() <= 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Mobile_300x250_Extra_4'); }); }
# </script>
# </div>
# </div></div>
# </div>
# <div class="sidebar-2-ad-desktop">
# <div id="div-ad-GrandOrder_Desktop_RR_300x250_B" style="margin:0px 0px 10px 0px;">
# <script>
# if(detectWidth() > 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Desktop_RR_300x250_B'); }); }
# </script>
# </div></div>
# <div class="views-element-container" id="block-views-block-popular-pages-block-3">
# <div class="popular-items-block popular-block">
# <h2>Popular Servants Today</h2>
# <ul>
# <li>
# <a href="/servant/koyanskaya-of-the-light">
# <span class="pages-ranking-number ranking-number-1">1</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2021-08/314_Koyanskaya_Icon.png?itok=z76djug-"/>
# </span>
# <span class="pages-ranking-title">
# Koyanskaya of Light
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/oberon">
# <span class="pages-ranking-number ranking-number-2">2</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2021-08/316_Oberon_Icon.png?itok=ZRKSPPPf"/>
# </span>
# <span class="pages-ranking-title">
# Oberon
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/morgan">
# <span class="pages-ranking-number ranking-number-3">3</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2021-06/309_Morgan_Icon.png?itok=kzVRRkls"/>
# </span>
# <span class="pages-ranking-title">
# Morgan
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/melusine">
# <span class="pages-ranking-number ranking-number-4">4</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2021-07/312_Melusine_Icon.png?itok=cI8OcXGs"/>
# </span>
# <span class="pages-ranking-title">
# Melusine
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/altria-pendragon">
# <span class="pages-ranking-number ranking-number-5">5</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2017-07/artoria.png?itok=MQDGg4x-"/>
# </span>
# <span class="pages-ranking-title">
# Altria Pendragon
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/koyanskaya-dark">
# <span class="pages-ranking-number ranking-number-6">6</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2021-12/334_Koyanskaya%20Darkness_Icon.png?itok=OoeT3sjZ"/>
# </span>
# <span class="pages-ranking-title">
# Koyanskaya of Darkness
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/altria-caster">
# <span class="pages-ranking-number ranking-number-7">7</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2020-08/284_Altria%20Caster_Icon.png?itok=iouuNsBU"/>
# </span>
# <span class="pages-ranking-title">
# Altria Caster
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/zhuge-liang-el-melloi-ii">
# <span class="pages-ranking-number ranking-number-8">8</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2017-07/037%20Zhuge%20Liang%20%28El-Melloi%20II%29%20icon.png?itok=hmPi3srV"/>
# </span>
# <span class="pages-ranking-title">
# Zhuge Liang (El-Melloi II)
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/tamamo-no-mae">
# <span class="pages-ranking-number ranking-number-9">9</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2017-09/MFiRy5d.png?itok=Vx7ClwOo"/>
# </span>
# <span class="pages-ranking-title">
# Tamamo-no-Mae
# </span>
# </a>
# </li>
# <li>
# <a href="/servant/altria-pendragon-lancer">
# <span class="pages-ranking-number ranking-number-10">10</span>
# <span class="pages-ranking-image">
# <img src="/sites/default/files/styles/thumbnail/public/2018-04/Icon_Servant_119.png?itok=4zXSgsDc"/>
# </span>
# <span class="pages-ranking-title">
# Altria Pendragon (Lancer)
# </span>
# </a>
# </li>
# </ul>
# <div> <div class="view view-popular-pages view-id-popular_pages view-display-id-block_3 js-view-dom-id-69a0722144c0b75c22c612a2f4ac802cc869d354b4fe4be391f90c0fd14cd68c">
# <div class="view-content">
# </div>
# <div class="view-footer">
# <a href="https://fgo.gamepress.gg/popular-servants-all">See All</a>
# <style>
# .block-views-blockpopular-pages-block-3 img {
#     min-width: 45px;
# }
# </style>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="sidebar-3-ad-desktop">
# <div id="div-ad-GrandOrder_Desktop_RR_300x250_C">
# <script>
# if(detectWidth() > 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Desktop_RR_300x250_C'); }); }
# </script>
# </div></div>
# <div class="hide-desktop">
# <div class="block block-block-content block-block-content8ebe7e34-e84a-4bb7-951e-d46c67ccf09d" id="block-latestposts">
# <h2>Latest Posts</h2>
# <div class="field field--name-field-read-more field--type-link field--label-hidden field__item"><a class="button" href="https://community.gamepress.gg/c/fate-grand-order">Read More</a></div>
# </div>
# </div>
# </aside>
# </main>
# <span class="gp-tier-modal">
# <div class="modal" id="gp-tier-modal">
# <div class="modal-content-gp-tier" id="modal-cont-gp-tier">
# <span class="remove" onclick="closeModalGP()"><i aria-hidden="true" class="fa fa-times-circle"></i></span>
# <div id="unit-expl-gp"></div>
# </div>
# </div>
# </span>
# <script>
#   var gpLoaded = false;
#     $(document).ready(function() {
#           bindButtons();
#       });
#
#     function bindButtons(){
#       var showButtons = document.getElementsByClassName("show-expl");
#           for(var i = 0; i < showButtons.length; i++){
#             showButtons[i].onclick = showModalGP;
#           }
#     }
#
#     function showModalGP(e){
#       document.getElementById("site-header").style.zIndex = "0";
#       var modal = document.getElementById('gp-tier-modal');
#       if(!modal){
#         return;
#       }
#       var content = $(e.target).data('content');
#       var title = $(e.target).data('title');
#       var titleID = title.replace(":", "");
#       let nid = $(e.target).data("nid");
#       if(nid){
#         titleID = nid;
#       }
#       var explDiv = document.getElementById(titleID + "-expl-container");
#       var text = decodeHtml(explDiv.innerHTML);
#       title = "<div class='expl-title'>" + title + "<\/div>"
#       var modal2 = document.getElementById("unit-expl-gp");
#       modal2.innerHTML = title + text;
#       modal.style.display = "block";
#       gpLoaded = false;
#     }
#
#     function closeModalGP(){
#       var modal = document.getElementById('gp-tier-modal');
#       if(!modal){
#         return;
#       }
#       modal.style.display = "none";
#       gpLoaded = true;
#       document.getElementById("site-header").style.zIndex = "";
#     }
#     $('body').click(function (e) {
#         if(typeof(isDBL) == 'undefined'){
#           var id = e.target.id;
#         var parents = document.getElementById("modal-cont-gp-tier");
#         var modal = document.getElementById("gp-tier-modal");
#         if(!modal){
#           return;
#         }
#         if(modal.style.display == "block" && gpLoaded && !(parents.contains(e.target))){
#           modal.style.display = "none";
#           document.getElementById("site-header").style.zIndex = "";
#           gpLoaded = false;
#         }
#         else{
#           gpLoaded = true;
#         }
#       }
#       function decodeHtml(html) {
#         var txt = document.createElement("textarea");
#         txt.innerHTML = html;
#         return txt.value;
#     }
#
#   });
# </script>
# <footer id="site-footer">
# <div class="outer-wrapper">
# <section class="footer-top">
# <div id="div-ad-GrandOrder_Desktop_728x90_BTF">
# <script>
# if(detectWidth() > 980) { googletag.cmd.push(function() { googletag.display('div-ad-GrandOrder_Desktop_728x90_BTF'); }); }
# </script>
# </div>
# </section>
# <section class="footer-bottom">
# <a class="footer-logo" href="http://gamepress.gg" target="_blank"><img src="https://gamepress.gg/GamePressNewLogo.png"/></a>
# <div class="footer-links">
# <ul>
# <li><a href="https://gamepress.gg/disclaimer" target="_blank">Disclaimer</a></li>
# <li><a href="https://gamepress.gg/privacy-policy" target="_blank">Privacy Policy</a></li>
# <li><a href="https://gamepress.gg/terms-of-use" target="_blank">Terms of Use</a></li>
# <li><a href="/cdn-cgi/l/email-protection#c7a4a8a9b3a6a4b387a0a6aaa2b7b5a2b4b4e9a0a0" target="_blank">Contact Us</a></li>
# </ul>
# </div>
# <div class="footer-dots">
# <i aria-hidden="true" class="fa fa-circle"></i>
# <i aria-hidden="true" class="fa fa-circle"></i>
# <i aria-hidden="true" class="fa fa-circle"></i>
# </div>
# <div class="footer-copyright">
# <p>Copyright (C) GamePress All Rights Reserved.</p>
# </div>
# <div class="footer-copyright">
# <p>Fate/Grand Order is Copyright Aniplex Inc., DELiGHTWORKS, Aniplex of America and Sony Music Entertainment (Japan) Inc. All images and names owned and trademarked by Aniplex Inc., DELiGHTWORKS, Aniplex of America and Sony Music Entertainment (Japan) Inc. are property of their respective owners.</p>
# </div>
# </section>
# </div>
# </footer>
# </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script data-drupal-selector="drupal-settings-json" type="application/json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"node\/1201","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","suppressDeprecationErrors":true,"ajaxPageState":{"libraries":"browserclass\/global-browserclass,classy\/base,classy\/messages,core\/drupal.collapse,core\/html5shiv,core\/normalize,gamepressbase\/global-scripts,gamepressbase\/global-styling,google_analytics\/google_analytics,main\/global-scripts,main\/global-styling,main\/js-header,node\/drupal.node,paragraphs\/drupal.paragraphs.unpublished,search_api_autocomplete\/search_api_autocomplete,system\/base,views\/views.module","theme":"gamepressbase","theme_token":null},"ajaxTrustedUrl":{"\/search":true},"google_analytics":{"trackOutbound":true,"trackMailto":true,"trackDownload":true,"trackDownloadExtensions":"7z|aac|arc|arj|asf|asx|avi|bin|csv|doc(x|m)?|dot(x|m)?|exe|flv|gif|gz|gzip|hqx|jar|jpe?g|js|mp(2|3|4|e?g)|mov(ie)?|msi|msp|pdf|phps|png|ppt(x|m)?|pot(x|m)?|pps(x|m)?|ppam|sld(x|m)?|thmx|qtm?|ra(m|r)?|sea|sit|tar|tgz|torrent|txt|wav|wma|wmv|wpd|xls(x|m|b)?|xlt(x|m)|xlam|xml|z|zip","trackColorbox":true},"search_api_autocomplete":{"site_search":{"auto_submit":true}},"user":{"uid":0,"permissionsHash":"31734aa3a8dce88774195ee6a5bfe5af1a4951cf697992dd94854149fb7bd359"}}</script>
# <script src="/sites/default/files/js/js_jUQUxkC82xaJsi5DwkJmhvzt3KCrdHfaKi61dMfymOQ.js"></script>
# </body>
# </html>

# %%
# Considere a tag <a> com href
child_links = soup.find_all('a', href=True)

# Salva
lista_url = []
for link in child_links:
    href = link['href']
    if href.startswith('/servant/'):
        full_url = f"https://fgo.gamepress.gg{href}"
        lista_url.append(full_url)

# Remove repetições, se existir
lista_url_filtrado = list(set(lista_url))
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/mash-kyrielight')
#lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/mash-ortinax')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/beast-iiir')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/solomon-grand-caster')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/solomon-true')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/goetia')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/beast-iiil')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/e-aqua-marie')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/e-flare-marie')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/beast-iv')
lista_url_filtrado.remove('https://fgo.gamepress.gg/servant/tiamat')
lista_url_filtrado.sort()
lista_url_filtrado
# Out:
# ['https://fgo.gamepress.gg/servant/abigail-williams',
#  'https://fgo.gamepress.gg/servant/abigail-williams-summer',
#  'https://fgo.gamepress.gg/servant/achilles',
#  'https://fgo.gamepress.gg/servant/alessandro-di-cagliostro',
#  'https://fgo.gamepress.gg/servant/alexander',
#  'https://fgo.gamepress.gg/servant/alice-kuonji',
#  'https://fgo.gamepress.gg/servant/altera',
#  'https://fgo.gamepress.gg/servant/altria-caster',
#  'https://fgo.gamepress.gg/servant/altria-caster-berserker',
#  'https://fgo.gamepress.gg/servant/altria-pendragon',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-alter',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-archer',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-lancer',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-lancer-alter',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-lily',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-rider-alter',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-ruler',
#  'https://fgo.gamepress.gg/servant/altria-pendragon-santa-alter',
#  'https://fgo.gamepress.gg/servant/amakusa-shirou',
#  'https://fgo.gamepress.gg/servant/amor-caren',
#  'https://fgo.gamepress.gg/servant/anastasia-nikolaevna-romanova',
#  'https://fgo.gamepress.gg/servant/anastasia-viy-archer',
#  'https://fgo.gamepress.gg/servant/andromeda',
#  'https://fgo.gamepress.gg/servant/anne-bonny-mary-read',
#  'https://fgo.gamepress.gg/servant/anne-bonny-mary-read-archer',
#  'https://fgo.gamepress.gg/servant/anra-mainiiu',
#  'https://fgo.gamepress.gg/servant/antonio-salieri',
#  'https://fgo.gamepress.gg/servant/aoko-aozaki',
#  'https://fgo.gamepress.gg/servant/aoko-aozaki-super',
#  'https://fgo.gamepress.gg/servant/arash',
#  'https://fgo.gamepress.gg/servant/archer-inferno',
#  'https://fgo.gamepress.gg/servant/archer-inferno-saber',
#  'https://fgo.gamepress.gg/servant/archer-shinjuku',
#  'https://fgo.gamepress.gg/servant/archetype-earth',
#  'https://fgo.gamepress.gg/servant/arjuna',
#  'https://fgo.gamepress.gg/servant/arjuna-alter',
#  'https://fgo.gamepress.gg/servant/arthur-pendragon-prototype',
#  'https://fgo.gamepress.gg/servant/asagami-fujino',
#  'https://fgo.gamepress.gg/servant/asclepius',
#  'https://fgo.gamepress.gg/servant/ashiya-douman',
#  'https://fgo.gamepress.gg/servant/assassin-nightless-city',
#  'https://fgo.gamepress.gg/servant/assassin-nightless-city-caster',
#  'https://fgo.gamepress.gg/servant/assassin-paraiso',
#  'https://fgo.gamepress.gg/servant/assassin-shinjuku',
#  'https://fgo.gamepress.gg/servant/asterios',
#  'https://fgo.gamepress.gg/servant/astolfo',
#  'https://fgo.gamepress.gg/servant/astolfo-saber',
#  'https://fgo.gamepress.gg/servant/astraea',
#  'https://fgo.gamepress.gg/servant/asvatthaman',
#  'https://fgo.gamepress.gg/servant/atalante',
#  'https://fgo.gamepress.gg/servant/atalante-alter',
#  'https://fgo.gamepress.gg/servant/attila-santa',
#  'https://fgo.gamepress.gg/servant/avenger-shinjuku',
#  'https://fgo.gamepress.gg/servant/avicebron',
#  'https://fgo.gamepress.gg/servant/baobhan-sith',
#  'https://fgo.gamepress.gg/servant/barghest',
#  'https://fgo.gamepress.gg/servant/bartholomew-roberts',
#  'https://fgo.gamepress.gg/servant/bb',
#  'https://fgo.gamepress.gg/servant/bb-summer',
#  'https://fgo.gamepress.gg/servant/bedivere',
#  'https://fgo.gamepress.gg/servant/beni-enma',
#  'https://fgo.gamepress.gg/servant/beowulf',
#  'https://fgo.gamepress.gg/servant/berserker-el-dorado',
#  'https://fgo.gamepress.gg/servant/bhima',
#  'https://fgo.gamepress.gg/servant/billy-kid',
#  'https://fgo.gamepress.gg/servant/boudica',
#  'https://fgo.gamepress.gg/servant/bradamante',
#  'https://fgo.gamepress.gg/servant/britomart',
#  'https://fgo.gamepress.gg/servant/brynhild',
#  'https://fgo.gamepress.gg/servant/brynhild-berserker',
#  'https://fgo.gamepress.gg/servant/caenis',
#  'https://fgo.gamepress.gg/servant/caenis-rider',
#  'https://fgo.gamepress.gg/servant/cait-cu-cerpriestess',
#  'https://fgo.gamepress.gg/servant/calamity-jane',
#  'https://fgo.gamepress.gg/servant/caligula',
#  'https://fgo.gamepress.gg/servant/carmilla',
#  'https://fgo.gamepress.gg/servant/carmilla-rider',
#  'https://fgo.gamepress.gg/servant/caster-midrash',
#  'https://fgo.gamepress.gg/servant/caster-nightless-city',
#  'https://fgo.gamepress.gg/servant/caster-okeanos',
#  'https://fgo.gamepress.gg/servant/chacha',
#  'https://fgo.gamepress.gg/servant/charlemagne',
#  'https://fgo.gamepress.gg/servant/charles-babbage',
#  'https://fgo.gamepress.gg/servant/charles-henri-sanson',
#  'https://fgo.gamepress.gg/servant/charlotte-corday',
#  'https://fgo.gamepress.gg/servant/charlotte-corday-caster',
#  'https://fgo.gamepress.gg/servant/chen-gong',
#  'https://fgo.gamepress.gg/servant/chevalier-deon',
#  'https://fgo.gamepress.gg/servant/chiron',
#  'https://fgo.gamepress.gg/servant/chloe-von-einzbern',
#  'https://fgo.gamepress.gg/servant/chloe-von-einzbern-avenger',
#  'https://fgo.gamepress.gg/servant/cleopatra',
#  'https://fgo.gamepress.gg/servant/cnoc-na-riabh',
#  'https://fgo.gamepress.gg/servant/count-monte-cristo',
#  'https://fgo.gamepress.gg/servant/cu-chulainn',
#  'https://fgo.gamepress.gg/servant/cu-chulainn-alter',
#  'https://fgo.gamepress.gg/servant/cu-chulainn-caster',
#  'https://fgo.gamepress.gg/servant/cu-chulainn-prototype',
#  'https://fgo.gamepress.gg/servant/daikokuten',
#  'https://fgo.gamepress.gg/servant/darius-iii',
#  'https://fgo.gamepress.gg/servant/david',
#  'https://fgo.gamepress.gg/servant/demon-king-nobunaga-oda-nobunaga',
#  'https://fgo.gamepress.gg/servant/diarmuid-ua-duibhne',
#  'https://fgo.gamepress.gg/servant/diarmuid-ua-duibhne-saber',
#  'https://fgo.gamepress.gg/servant/dioscuri',
#  'https://fgo.gamepress.gg/servant/dobrynya-nikitich',
#  'https://fgo.gamepress.gg/servant/don-quixote',
#  'https://fgo.gamepress.gg/servant/durga',
#  'https://fgo.gamepress.gg/servant/duryodhana',
#  'https://fgo.gamepress.gg/servant/edmond-dantes',
#  'https://fgo.gamepress.gg/servant/edward-teach',
#  'https://fgo.gamepress.gg/servant/elisabeth-bathory',
#  'https://fgo.gamepress.gg/servant/elisabeth-bathory-brave',
#  'https://fgo.gamepress.gg/servant/elisabeth-bathory-cinderella',
#  'https://fgo.gamepress.gg/servant/elisabeth-bathory-halloween',
#  'https://fgo.gamepress.gg/servant/elisabeth-bathory-kumonryu',
#  'https://fgo.gamepress.gg/servant/emiya',
#  'https://fgo.gamepress.gg/servant/emiya-alter',
#  'https://fgo.gamepress.gg/servant/emiya-assassin',
#  'https://fgo.gamepress.gg/servant/enkidu',
#  'https://fgo.gamepress.gg/servant/ereshkigal',
#  'https://fgo.gamepress.gg/servant/eric-bloodaxe',
#  'https://fgo.gamepress.gg/servant/europa',
#  'https://fgo.gamepress.gg/servant/euryale',
#  'https://fgo.gamepress.gg/servant/fergus-mac-roich',
#  'https://fgo.gamepress.gg/servant/fionn-mac-cumhaill',
#  'https://fgo.gamepress.gg/servant/first-hassan',
#  'https://fgo.gamepress.gg/servant/francis-drake',
#  'https://fgo.gamepress.gg/servant/frankenstein',
#  'https://fgo.gamepress.gg/servant/frankenstein-saber',
#  'https://fgo.gamepress.gg/servant/fuuma-kotarou',
#  'https://fgo.gamepress.gg/servant/gaius-julius-caesar',
#  'https://fgo.gamepress.gg/servant/galatea',
#  'https://fgo.gamepress.gg/servant/ganesha-jinako',
#  'https://fgo.gamepress.gg/servant/gareth',
#  'https://fgo.gamepress.gg/servant/gareth-saber',
#  'https://fgo.gamepress.gg/servant/gawain',
#  'https://fgo.gamepress.gg/servant/georgios',
#  'https://fgo.gamepress.gg/servant/geronimo',
#  'https://fgo.gamepress.gg/servant/gilgamesh',
#  'https://fgo.gamepress.gg/servant/gilgamesh-caster',
#  'https://fgo.gamepress.gg/servant/gilles-de-rais',
#  'https://fgo.gamepress.gg/servant/gilles-de-rais-caster',
#  'https://fgo.gamepress.gg/servant/gorgon',
#  'https://fgo.gamepress.gg/servant/gray',
#  'https://fgo.gamepress.gg/servant/grigori-rasputin',
#  'https://fgo.gamepress.gg/servant/habetrot',
#  'https://fgo.gamepress.gg/servant/hai-ba-trung',
#  'https://fgo.gamepress.gg/servant/hans-christian-andersen',
#  'https://fgo.gamepress.gg/servant/hassan-cursed-arm',
#  'https://fgo.gamepress.gg/servant/hassan-hundred-personas',
#  'https://fgo.gamepress.gg/servant/hassan-serenity',
#  'https://fgo.gamepress.gg/servant/hassan-shining-star',
#  'https://fgo.gamepress.gg/servant/hektor',
#  'https://fgo.gamepress.gg/servant/helena-blavatsky',
#  'https://fgo.gamepress.gg/servant/helena-blavatsky-archer',
#  'https://fgo.gamepress.gg/servant/henry-jekyll-hyde',
#  'https://fgo.gamepress.gg/servant/hephaistion',
#  'https://fgo.gamepress.gg/servant/heracles',
#  'https://fgo.gamepress.gg/servant/hibiki-chikagi',
#  'https://fgo.gamepress.gg/servant/hijikata-toshizo',
#  'https://fgo.gamepress.gg/servant/hildr-assassin',
#  'https://fgo.gamepress.gg/servant/himiko',
#  'https://fgo.gamepress.gg/servant/houzouin-inshun',
#  'https://fgo.gamepress.gg/servant/huang-feihu',
#  'https://fgo.gamepress.gg/servant/huyan-zhuo',
#  'https://fgo.gamepress.gg/servant/ibaraki-douji',
#  'https://fgo.gamepress.gg/servant/ibaraki-douji-lancer',
#  'https://fgo.gamepress.gg/servant/ibuki-douji',
#  'https://fgo.gamepress.gg/servant/ibuki-douji-berserker',
#  'https://fgo.gamepress.gg/servant/illyasviel-von-einzbern',
#  'https://fgo.gamepress.gg/servant/illyasviel-von-einzbern-archer',
#  'https://fgo.gamepress.gg/servant/irisviel-holy-grail',
#  'https://fgo.gamepress.gg/servant/ishtar',
#  'https://fgo.gamepress.gg/servant/ishtar-rider',
#  'https://fgo.gamepress.gg/servant/iskandar',
#  'https://fgo.gamepress.gg/servant/ivan-terrible',
#  'https://fgo.gamepress.gg/servant/iyo',
#  'https://fgo.gamepress.gg/servant/izumo-no-okuni',
#  'https://fgo.gamepress.gg/servant/jack-ripper',
#  'https://fgo.gamepress.gg/servant/jacques-de-molay',
#  'https://fgo.gamepress.gg/servant/jaguar-warrior',
#  'https://fgo.gamepress.gg/servant/james-moriarty-ruler',
#  'https://fgo.gamepress.gg/servant/jason',
#  'https://fgo.gamepress.gg/servant/jeanne-darc',
#  'https://fgo.gamepress.gg/servant/jeanne-darc-alter',
#  'https://fgo.gamepress.gg/servant/jeanne-darc-alter-santa-lily',
#  'https://fgo.gamepress.gg/servant/jeanne-darc-archer',
#  'https://fgo.gamepress.gg/servant/jeanne-darc-berserker-alter',
#  'https://fgo.gamepress.gg/servant/jing-ke',
#  'https://fgo.gamepress.gg/servant/kama',
#  'https://fgo.gamepress.gg/servant/kama-avenger',
#  'https://fgo.gamepress.gg/servant/karna',
#  'https://fgo.gamepress.gg/servant/karna-santa',
#  'https://fgo.gamepress.gg/servant/kashin-koji',
#  'https://fgo.gamepress.gg/servant/katou-danzo',
#  'https://fgo.gamepress.gg/servant/katsushika-hokusai',
#  'https://fgo.gamepress.gg/servant/katsushika-hokusai-saber',
#  'https://fgo.gamepress.gg/servant/kid-gilgamesh',
#  'https://fgo.gamepress.gg/servant/kiichi-hogen',
#  'https://fgo.gamepress.gg/servant/kijyo-koyo',
#  'https://fgo.gamepress.gg/servant/kingprotea',
#  'https://fgo.gamepress.gg/servant/kiyohime',
#  'https://fgo.gamepress.gg/servant/kiyohime-lancer',
#  'https://fgo.gamepress.gg/servant/konstantinos-xi',
#  'https://fgo.gamepress.gg/servant/koyanskaya-dark',
#  'https://fgo.gamepress.gg/servant/koyanskaya-of-the-light',
#  'https://fgo.gamepress.gg/servant/kriemhild',
#  'https://fgo.gamepress.gg/servant/kukulkan',
#  'https://fgo.gamepress.gg/servant/kyokutei-bakin',
#  'https://fgo.gamepress.gg/servant/lady-avalon',
#  'https://fgo.gamepress.gg/servant/lakshmi-bai',
#  'https://fgo.gamepress.gg/servant/lancelot',
#  'https://fgo.gamepress.gg/servant/lancelot-saber',
#  'https://fgo.gamepress.gg/servant/larva-tiamat',
#  'https://fgo.gamepress.gg/servant/leonardo-da-vinci',
#  'https://fgo.gamepress.gg/servant/leonardo-da-vinci-rider',
#  'https://fgo.gamepress.gg/servant/leonardo-da-vinci-ruler',
#  'https://fgo.gamepress.gg/servant/leonidas',
#  'https://fgo.gamepress.gg/servant/li-shuwen',
#  'https://fgo.gamepress.gg/servant/li-shuwen-assassin',
#  'https://fgo.gamepress.gg/servant/locusta',
#  'https://fgo.gamepress.gg/servant/lu-bu-fengxian',
#  'https://fgo.gamepress.gg/servant/manannan-mac-lir-bazett',
#  'https://fgo.gamepress.gg/servant/mandricardo',
#  'https://fgo.gamepress.gg/servant/marie-antoinette',
#  'https://fgo.gamepress.gg/servant/marie-antoinette-alter',
#  'https://fgo.gamepress.gg/servant/marie-antoinette-caster',
#  'https://fgo.gamepress.gg/servant/mary-anning',
#  'https://fgo.gamepress.gg/servant/mash-ortinax',
#  'https://fgo.gamepress.gg/servant/mata-hari',
#  'https://fgo.gamepress.gg/servant/mecha-eli-chan',
#  'https://fgo.gamepress.gg/servant/mecha-eli-chan-mkii',
#  'https://fgo.gamepress.gg/servant/medea',
#  'https://fgo.gamepress.gg/servant/medea-lily',
#  'https://fgo.gamepress.gg/servant/medusa',
#  'https://fgo.gamepress.gg/servant/medusa-lancer',
#  'https://fgo.gamepress.gg/servant/medusa-saber',
#  'https://fgo.gamepress.gg/servant/meltryllis',
#  'https://fgo.gamepress.gg/servant/melusine',
#  'https://fgo.gamepress.gg/servant/melusine-ruler',
#  'https://fgo.gamepress.gg/servant/mephistopheles',
#  'https://fgo.gamepress.gg/servant/merlin',
#  'https://fgo.gamepress.gg/servant/minamoto-no-raikou',
#  'https://fgo.gamepress.gg/servant/minamoto-no-raikou-lancer',
#  'https://fgo.gamepress.gg/servant/minamoto-no-raikou-ushi-gozen',
#  'https://fgo.gamepress.gg/servant/minamoto-no-tametomo',
#  'https://fgo.gamepress.gg/servant/miss-crane',
#  'https://fgo.gamepress.gg/servant/miyamoto-iori',
#  'https://fgo.gamepress.gg/servant/miyamoto-musashi',
#  'https://fgo.gamepress.gg/servant/miyamoto-musashi-berserker',
#  'https://fgo.gamepress.gg/servant/miyu-edelfelt',
#  'https://fgo.gamepress.gg/servant/mordred',
#  'https://fgo.gamepress.gg/servant/mordred-rider',
#  'https://fgo.gamepress.gg/servant/morgan',
#  'https://fgo.gamepress.gg/servant/mori-nagayoshi',
#  'https://fgo.gamepress.gg/servant/murasaki-shikibu',
#  'https://fgo.gamepress.gg/servant/murasaki-shikibu-rider',
#  'https://fgo.gamepress.gg/servant/musashibou-benkei',
#  'https://fgo.gamepress.gg/servant/mysterious-alter-ego-l',
#  'https://fgo.gamepress.gg/servant/mysterious-heroine-x',
#  'https://fgo.gamepress.gg/servant/mysterious-heroine-x-alter',
#  'https://fgo.gamepress.gg/servant/mysterious-heroine-xx',
#  'https://fgo.gamepress.gg/servant/mysterious-idol-x-alter',
#  'https://fgo.gamepress.gg/servant/mysterious-ranmaru-x',
#  'https://fgo.gamepress.gg/servant/nagakura-shinpachi',
#  'https://fgo.gamepress.gg/servant/nagao-kagetora',
#  'https://fgo.gamepress.gg/servant/napoleon',
#  'https://fgo.gamepress.gg/servant/nemo',
#  'https://fgo.gamepress.gg/servant/nemo-santa',
#  'https://fgo.gamepress.gg/servant/nero-claudius',
#  'https://fgo.gamepress.gg/servant/nero-claudius-bride',
#  'https://fgo.gamepress.gg/servant/nero-claudius-caster',
#  'https://fgo.gamepress.gg/servant/nezha',
#  'https://fgo.gamepress.gg/servant/nightingale',
#  'https://fgo.gamepress.gg/servant/nightingale-santa',
#  'https://fgo.gamepress.gg/servant/nikola-tesla',
#  'https://fgo.gamepress.gg/servant/nitocris',
#  'https://fgo.gamepress.gg/servant/nitocris-alter',
#  'https://fgo.gamepress.gg/servant/nitocris-assassin',
#  'https://fgo.gamepress.gg/servant/nursery-rhyme',
#  'https://fgo.gamepress.gg/servant/oberon',
#  'https://fgo.gamepress.gg/servant/oda-nobukatsu',
#  'https://fgo.gamepress.gg/servant/oda-nobunaga',
#  'https://fgo.gamepress.gg/servant/oda-nobunaga-berserker',
#  'https://fgo.gamepress.gg/servant/odysseus',
#  'https://fgo.gamepress.gg/servant/okada-izo',
#  'https://fgo.gamepress.gg/servant/okita-j-souji',
#  'https://fgo.gamepress.gg/servant/okita-souji',
#  'https://fgo.gamepress.gg/servant/okita-souji-alter',
#  'https://fgo.gamepress.gg/servant/okita-souji-saber-alter',
#  'https://fgo.gamepress.gg/servant/orion',
#  'https://fgo.gamepress.gg/servant/ortlinde-assassin',
#  'https://fgo.gamepress.gg/servant/osakabehime',
#  'https://fgo.gamepress.gg/servant/osakabehime-archer',
#  'https://fgo.gamepress.gg/servant/ozymandias',
#  'https://fgo.gamepress.gg/servant/paracelsus-von-hohenheim',
#  'https://fgo.gamepress.gg/servant/paris',
#  'https://fgo.gamepress.gg/servant/parvati',
#  'https://fgo.gamepress.gg/servant/passionlip',
#  'https://fgo.gamepress.gg/servant/paul-bunyan',
#  'https://fgo.gamepress.gg/servant/percival',
#  'https://fgo.gamepress.gg/servant/phantom-opera',
#  'https://fgo.gamepress.gg/servant/pope-johanna',
#  'https://fgo.gamepress.gg/servant/prince-lan-ling',
#  'https://fgo.gamepress.gg/servant/ptolemy',
#  'https://fgo.gamepress.gg/servant/qin-liangyu',
#  'https://fgo.gamepress.gg/servant/qin-shi-huang',
#  'https://fgo.gamepress.gg/servant/queen-medb',
#  'https://fgo.gamepress.gg/servant/queen-medb-saber',
#  'https://fgo.gamepress.gg/servant/quetzalcoatl',
#  'https://fgo.gamepress.gg/servant/quetzalcoatl-sambasanta',
#  'https://fgo.gamepress.gg/servant/rama',
#  'https://fgo.gamepress.gg/servant/red-hare',
#  'https://fgo.gamepress.gg/servant/rider-resistance',
#  'https://fgo.gamepress.gg/servant/robin-hood',
#  'https://fgo.gamepress.gg/servant/roland',
#  'https://fgo.gamepress.gg/servant/romulus',
#  'https://fgo.gamepress.gg/servant/romulusquirinus',
#  'https://fgo.gamepress.gg/servant/ryougi-shiki-assassin',
#  'https://fgo.gamepress.gg/servant/ryougi-shiki-saber',
#  'https://fgo.gamepress.gg/servant/saika-magoichi',
#  'https://fgo.gamepress.gg/servant/saint-martha',
#  'https://fgo.gamepress.gg/servant/saint-martha-ruler',
#  'https://fgo.gamepress.gg/servant/saint-martha-santa',
#  'https://fgo.gamepress.gg/servant/saito-hajime',
#  'https://fgo.gamepress.gg/servant/sakamoto-ryouma',
#  'https://fgo.gamepress.gg/servant/sakamoto-ryouma-lancer',
#  'https://fgo.gamepress.gg/servant/sakata-kintoki',
#  'https://fgo.gamepress.gg/servant/sakata-kintoki-rider',
#  'https://fgo.gamepress.gg/servant/salome',
#  'https://fgo.gamepress.gg/servant/sasaki-kojirou',
#  'https://fgo.gamepress.gg/servant/savior-aesc',
#  'https://fgo.gamepress.gg/servant/scathach',
#  'https://fgo.gamepress.gg/servant/scathach-assassin',
#  'https://fgo.gamepress.gg/servant/scathach-skadi',
#  'https://fgo.gamepress.gg/servant/scathach-skadi-ruler',
#  'https://fgo.gamepress.gg/servant/sei-shounagon',
#  'https://fgo.gamepress.gg/servant/sei-shounagon-berserker',
#  'https://fgo.gamepress.gg/servant/semiramis',
#  'https://fgo.gamepress.gg/servant/sen-no-rikyu',
#  'https://fgo.gamepress.gg/servant/senji-muramasa',
#  'https://fgo.gamepress.gg/servant/sessyoin-kiara',
#  'https://fgo.gamepress.gg/servant/sessyoin-kiara-moon-cancer',
#  'https://fgo.gamepress.gg/servant/setanta',
#  'https://fgo.gamepress.gg/servant/sherlock-holmes',
#  'https://fgo.gamepress.gg/servant/shuten-douji',
#  'https://fgo.gamepress.gg/servant/shuten-douji-caster',
#  'https://fgo.gamepress.gg/servant/sieg',
#  'https://fgo.gamepress.gg/servant/siegfried',
#  'https://fgo.gamepress.gg/servant/sigurd',
#  'https://fgo.gamepress.gg/servant/sima-yi-reines',
#  'https://fgo.gamepress.gg/servant/sitonai',
#  'https://fgo.gamepress.gg/servant/sodoms-beast-draco',
#  'https://fgo.gamepress.gg/servant/soujuurou-shizuki',
#  'https://fgo.gamepress.gg/servant/space-ishtar',
#  'https://fgo.gamepress.gg/servant/spartacus',
#  'https://fgo.gamepress.gg/servant/stheno',
#  'https://fgo.gamepress.gg/servant/sugitani-zenjubou',
#  'https://fgo.gamepress.gg/servant/super-bunyan',
#  'https://fgo.gamepress.gg/servant/super-orion',
#  'https://fgo.gamepress.gg/servant/suzuka-gozen',
#  'https://fgo.gamepress.gg/servant/suzuka-gozen-rider',
#  'https://fgo.gamepress.gg/servant/taigong-wang',
#  'https://fgo.gamepress.gg/servant/taira-no-kagekiyo',
#  'https://fgo.gamepress.gg/servant/taisui-xingjun',
#  'https://fgo.gamepress.gg/servant/takasugi-shinsaku',
#  'https://fgo.gamepress.gg/servant/takeda-shingen-takeda-harunobu',
#  'https://fgo.gamepress.gg/servant/tamamo-cat',
#  'https://fgo.gamepress.gg/servant/tamamo-no-mae',
#  'https://fgo.gamepress.gg/servant/tamamo-no-mae-lancer',
#  'https://fgo.gamepress.gg/servant/tawara-touta',
#  'https://fgo.gamepress.gg/servant/tezcatlipoca',
#  'https://fgo.gamepress.gg/servant/theseus',
#  'https://fgo.gamepress.gg/servant/thomas-edison',
#  'https://fgo.gamepress.gg/servant/thrud-assassin',
#  'https://fgo.gamepress.gg/servant/tlaloc',
#  'https://fgo.gamepress.gg/servant/tristan',
#  'https://fgo.gamepress.gg/servant/udk-barghest',
#  'https://fgo.gamepress.gg/servant/uesugi-kenshin',
#  'https://fgo.gamepress.gg/servant/ushiwakamaru',
#  'https://fgo.gamepress.gg/servant/ushiwakamaru-assassin',
#  'https://fgo.gamepress.gg/servant/utsumi-erice',
#  'https://fgo.gamepress.gg/servant/utsumi-erice-avenger',
#  'https://fgo.gamepress.gg/servant/valkyrie',
#  'https://fgo.gamepress.gg/servant/van-gogh',
#  'https://fgo.gamepress.gg/servant/vlad-iii',
#  'https://fgo.gamepress.gg/servant/vlad-iii-extra',
#  'https://fgo.gamepress.gg/servant/voyager',
#  'https://fgo.gamepress.gg/servant/vritra',
#  'https://fgo.gamepress.gg/servant/wandjina',
#  'https://fgo.gamepress.gg/servant/watanabe-no-tsuna',
#  'https://fgo.gamepress.gg/servant/william-shakespeare',
#  'https://fgo.gamepress.gg/servant/william-tell',
#  'https://fgo.gamepress.gg/servant/wolfgang-amadeus-mozart',
#  'https://fgo.gamepress.gg/servant/xiang-yu',
#  'https://fgo.gamepress.gg/servant/xu-fu',
#  'https://fgo.gamepress.gg/servant/xuanzang-sanzang',
#  'https://fgo.gamepress.gg/servant/yagyu-munenori',
#  'https://fgo.gamepress.gg/servant/yamanami-keisuke',
#  'https://fgo.gamepress.gg/servant/yamato-takeru',
#  'https://fgo.gamepress.gg/servant/yang-guifei',
#  'https://fgo.gamepress.gg/servant/yu-mei-ren',
#  'https://fgo.gamepress.gg/servant/yu-mei-ren-lancer',
#  'https://fgo.gamepress.gg/servant/yui-shousetsu',
#  'https://fgo.gamepress.gg/servant/zenobia',
#  'https://fgo.gamepress.gg/servant/zhang-jue',
#  'https://fgo.gamepress.gg/servant/zhuge-liang-el-melloi-ii']

# %%
df = pd.DataFrame({'Name' :['Mash Kyrielight', 'Mash Kyrielight(Ortinax)'], 'Class' :['Shielder', 'Shielder'], 'Star' :['4', '4'],
                   'Traits' :['Humanoid, Servant, Female, Riding, Heaven or Earth, Weak to Enuma Elish, Spiritron Dress User, Knights of the Round Table, Pseudo-Servant, Hominidae, Summer Form',
                              'Humanoid, Servant, Female, Riding, Heaven or Earth, Weak to Enuma Elish, Spiritron Dress User, Knights of the Round Table, Pseudo-Servant, Hominidae, Summer Form'],
                   'Tags' :['DEF Support, Damage Cut, Support, Target Focus, Self NP Gain Up, Invincibility Support, NP Gauge Support, ATK Support, Support Arts NP',
                            'DEF Support, Damage Cut, Support, Target Focus, Self NP Gain Up, Invincibility Support, NP Gauge Support, ATK Support, Support Arts NP'],
                  'Skill 1 Base - Nome' :['Transient Wall of Snowflakes', 'Bunker Bolt A'],
                  'Skill 1 Base - Descricao' :['Increase DEF for all allies (3 turns).',
                                               'Increase own Buster Card effectiveness (1 time, 3 turns).Increase own Buster Card Critical Strength (1 time, 3 turns).'],
                  'Skill 1 Upgrade - Nome' :['Honorable Wall of Snowflakes', 'Black Barrel B'],
                  'Skill 1 Upgrade - Descricao' :['Increase DEF for all allies (3 turns).Apply Damage Cut by 2000 for all allies (1 time).',
                                                  'ncrease own Buster Card effectiveness (1 time, 3 turns).Increase own Buster Card Critical Strength (1 time, 3 turns).Apply Ignore DEF to self (3 turns).'],
                  'Skill 2 Base - Nome' :['Obscurant Wall of Chalk', 'Amalgam Goad D'],
                  'Skill 2 Base - Descricao' :['Apply Invincible to an ally (1 turn).Increase NP Gauge for an ally.', 'Apply Target Focus to self (1 turn).Increase own NP Gauge.'],
                  'Skill 2 Upgrade - Nome' :['none', 'none'],
                  'Skill 2 Upgrade - Descricao' :['none', 'none'],
                  'Skill 3 Base - Nome' :['Shield of Rousing Resolution', 'Tragic Shield of Rousal'],
                  'Skill 3 Base - Descricao' :['Apply Target Focus to self (1 turn).Increase own NP Gain (1 turn).', 'Apply Invincible to self (1 turn).Apply Target Focus to self (1 turn).Decrease own HP. [Demerit]'],
                  'Skill 3 Upgrade - Nome' :['none', 'none'],
                  'Skill 3 Upgrade - Descricao' :['none', 'none'],
                  'NP Base - Nome' :['Lord Chaldeas D', '	Mold Camelot D'],
                  'NP Base - Descricao' :['Apply Incoming Damage Cut for all allies (3 turns). Overcharge: Increase DEF for all allies (3 turns).',
                                          'Apply Incoming Damage Cut for all allies (3 times, 5 turns). Overcharge: Increase DEF for all allies (3 turns).'],
                  'NP Upgrade - Nome' :['Lord Camelot (Upgrade 1) B+++', 'none'],
                  'NP Upgrade - Descricao' :['Apply Incoming Damage Cut for all allies (3 turns).Increase ATK for all allies by 30% except self (3 turns). Overcharge: Increase DEF for all allies (3 turns).', 'none']
                  })

# %%
#first_url = lista_url_filtrado[19]
#first_url
#response = requests.get(first_url, timeout=15)

import time

i = 0

for url in lista_url_filtrado:
    #time.sleep(10)
    response = requests.get(url)

    soup = BeautifulSoup(response.content, 'html.parser')

    #Nome
    servant_div_1 = soup.find('div', id = 'page-title')
    servant_h1 = servant_div_1.find('h1')
    servant_name = servant_h1.get_text(strip=True)

    #Classe
    servant_div_2 = soup.find('div', id = 'servant-subheader')
    servant_class_temp = servant_div_2.find('span', class_='class-title')
    servant_class = servant_class_temp.get_text(strip=True)

    #Rank
    servant_table_1 = soup.find('table', class_ = 'assorted-info')
    th_elements = servant_table_1.find_all('th')
    star = None
    for th in th_elements:
      if th.get_text(strip=True) == 'Cost':
        next_td = th.find_next_sibling('td')
        value = next_td.get_text(strip=True)
        if value == '3':
          star = 1
        elif value == '4':
          star = 2
        elif value == '7':
          star = 3
        elif value == '12':
          star = 4
        elif value == '16':
          star = 5
        break

    #Traits
    servant_div_3 = soup.find('div', class_ = 'traits-list-servant')
    if servant_div_3:
        servant_a_list = servant_div_3.find_all('a')
        traits = []
        for a in servant_a_list:
            traits.append(a.get_text(strip=True))

    #Tags
    servant_div_4 = soup.find('div', class_ = 'servant-tags-list clearfix')
    if servant_div_4:
        servant_a_list = servant_div_4.find_all('a')
        tags = []
        for a in servant_a_list:
            tags.append(a.get_text(strip=True))

    #Skills
    id_skills = soup.find('div', id='skills')

    class_skills = id_skills.find('div', class_='field field--name-field-servant-skills field--type-entity-reference-revisions field--label-hidden field__items')
    skill_raw_1 = class_skills.find('div', class_='field__item')
    skill_raw_2 = skill_raw_1.find_next_sibling('div', class_='field__item')
    skill_raw_3 = skill_raw_2.find_next_sibling('div', class_='field__item')

    #Skill 1
    servant_skill_single_1 = skill_raw_1.find('div', class_='servant-skill-single')
    servant_skill_upgrade_1 = skill_raw_1.find('div', class_='servant-skill-upgrade')

    #Skill 1 base
    servant_skill_single_1_name_raw = servant_skill_single_1.find('span', class_='field field--name-title field--type-string field--label-hidden')
    servant_skill_single_1_name = servant_skill_single_1_name_raw.get_text(strip=True)

    servant_skill_single_1_description_raw = servant_skill_single_1.find('p')
    servant_skill_single_1_description = servant_skill_single_1_description_raw.get_text(strip=True)

    #Skill 1 upgrade
    if servant_skill_upgrade_1:
        servant_skill_upgrade_1_name_raw = servant_skill_upgrade_1.find('span', class_='field field--name-title field--type-string field--label-hidden')
        servant_skill_upgrade_1_name = servant_skill_upgrade_1_name_raw.get_text(strip=True)

        servant_skill_upgrade_1_description_raw = servant_skill_upgrade_1.find('p')
        servant_skill_upgrade_1_description = servant_skill_upgrade_1_description_raw.get_text(strip=True)
    else:
        servant_skill_upgrade_1_name = None
        servant_skill_upgrade_1_description = None


    #Skill 2
    servant_skill_single_2 = skill_raw_2.find('div', class_='servant-skill-single')
    servant_skill_upgrade_2 = skill_raw_2.find('div', class_='servant-skill-upgrade')

    #Skill 2 base
    servant_skill_single_2_name_raw = servant_skill_single_2.find('span', class_='field field--name-title field--type-string field--label-hidden')
    servant_skill_single_2_name = servant_skill_single_2_name_raw.get_text(strip=True)

    servant_skill_single_2_description_raw = servant_skill_single_2.find('p')
    servant_skill_single_2_description = servant_skill_single_2_description_raw.get_text(strip=True)

    #Skill 2 upgrade
    if servant_skill_upgrade_2:
        servant_skill_upgrade_2_name_raw = servant_skill_upgrade_2.find('span', class_='field field--name-title field--type-string field--label-hidden')
        servant_skill_upgrade_2_name = servant_skill_upgrade_2_name_raw.get_text(strip=True)

        servant_skill_upgrade_2_description_raw = servant_skill_upgrade_2.find('p')
        servant_skill_upgrade_2_description = servant_skill_upgrade_2_description_raw.get_text(strip=True)
    else:
        servant_skill_upgrade_2_name = None
        servant_skill_upgrade_2_description = None

    #Skill 3
    servant_skill_single_3 = skill_raw_3.find('div', class_='servant-skill-single')
    servant_skill_upgrade_3 = skill_raw_3.find('div', class_='servant-skill-upgrade')

    #Skill 3 base
    servant_skill_single_3_name_raw = servant_skill_single_3.find('span', class_='field field--name-title field--type-string field--label-hidden')
    servant_skill_single_3_name = servant_skill_single_3_name_raw.get_text(strip=True)

    servant_skill_single_3_description_raw = servant_skill_single_3.find('p')
    servant_skill_single_3_description = servant_skill_single_3_description_raw.get_text(strip=True)

    #Skill 3 upgrade
    if servant_skill_upgrade_3:
        servant_skill_upgrade_3_name_raw = servant_skill_upgrade_3.find('span', class_='field field--name-title field--type-string field--label-hidden')
        servant_skill_upgrade_3_name = servant_skill_upgrade_3_name_raw.get_text(strip=True)

        servant_skill_upgrade_3_description_raw = servant_skill_upgrade_3.find('p')
        servant_skill_upgrade_3_description = servant_skill_upgrade_3_description_raw.get_text(strip=True)
    else:
        servant_skill_upgrade_3_name = None
        servant_skill_upgrade_3_description = None

    #NP
    class_np = soup.find('div', class_='np-base-container')

    servant_np_single = class_np.find('div', class_='servant-skill-single servant-skill-base np-skill-single')
    servant_np_upgrade = class_np.find('div', class_='np-upgrades')

    #NP base
    servant_np_single_name_raw_f = servant_np_single.find('div', class_='servant-skill-right')
    servant_np_single_name_raw = servant_np_single_name_raw_f.find('span', class_='field field--name-title field--type-string field--label-hidden')
    servant_np_single_name = servant_np_single_name_raw.get_text(strip=True)

    servant_np_single_description_raw_f = servant_np_single.find('div', class_='servant-skill-right')
    servant_np_single_description_raw = servant_np_single_description_raw_f.find('p')
    servant_np_single_description = servant_np_single_description_raw.get_text(strip=True)

    servant_np_single_description_over_p = servant_np_single_description_raw.find_next_sibling('p')
    servant_np_single_description_over_text_raw = servant_np_single_description_over_p.find('p')
    servant_np_single_description_over_text = servant_np_single_description_over_text_raw.get_text(strip=True)

    servant_np_single_description = servant_np_single_description + ' Overcharge: ' + servant_np_single_description_over_text

    #NP upgrade
    if servant_np_upgrade:
        servant_np_upgrade_name_raw_f = servant_np_upgrade.find('div', class_='servant-skill-right')
        servant_np_upgrade_name_raw = servant_np_upgrade_name_raw_f.find('span', class_='field field--name-title field--type-string field--label-hidden')
        servant_np_upgrade_name = servant_np_upgrade_name_raw.get_text(strip=True)

        servant_np_upgrade_description_raw_f = servant_np_upgrade.find('div', class_='servant-skill-right')
        servant_np_upgrade_description_raw = servant_np_upgrade_description_raw_f.find('p')
        servant_np_upgrade_description_over_p = servant_np_upgrade_description_raw.find_next_sibling('p')
        servant_np_upgrade_description = servant_np_upgrade_description_over_p.get_text(strip=True)

        servant_np_upgrade_description_over_text_raw_sp = servant_np_upgrade_description_over_p.find_next_sibling('p')
        servant_np_upgrade_description_over_text_raw = servant_np_upgrade_description_over_text_raw_sp.find('p')

        if servant_np_upgrade_description_over_text_raw == None:
          servant_np_upgrade_description_raw_f = servant_np_upgrade.find('div', class_='servant-skill-right')
          servant_np_upgrade_description_raw = servant_np_upgrade_description_raw_f.find('p')
          servant_np_upgrade_description_over_p = servant_np_upgrade_description_raw.find_next_sibling('p')
          servant_np_upgrade_description = servant_np_upgrade_description_over_p.get_text(strip=True)

          servant_np_upgrade_description_over_text_raw_sp = servant_np_upgrade_description_over_p.find_next_sibling('p')
          servant_np_upgrade_description_over_text_raw = servant_np_upgrade_description_over_text_raw_sp.get_text(strip=True)

          teste = servant_np_upgrade_description_over_text_raw.replace('<Overcharge>', '')

          servant_np_upgrade_description = 'Overcharge: ' + teste
        else:

            servant_np_upgrade_description_over_text = servant_np_upgrade_description_over_text_raw.get_text(strip=True)

            servant_np_upgrade_description = servant_np_upgrade_description + ' Overcharge: ' + servant_np_upgrade_description_over_text
    else:
      servant_np_upgrade_name = None
      servant_np_upgrade_description = None

    #DF
    df.loc[len(df.index)] = [servant_name, servant_class, star, traits, tags,
                         servant_skill_single_1_name, servant_skill_single_1_description, servant_skill_upgrade_1_name, servant_skill_upgrade_1_description,
                         servant_skill_single_2_name, servant_skill_single_2_description, servant_skill_upgrade_2_name, servant_skill_upgrade_2_description,
                         servant_skill_single_3_name, servant_skill_single_3_description, servant_skill_upgrade_3_name, servant_skill_upgrade_3_description,
                         servant_np_single_name, servant_np_single_description, servant_np_upgrade_name, servant_np_upgrade_description]

    #df = pd.concat([df, new_row], ignore_index=True)
    print(servant_name, i)
    i += 1

#df.to_csv('servants.csv', index=False)
#df.to_csv('servants.csv')
df
# Out:
# Uesugi Kenshin 0
# Ushiwakamaru 1
# Ushiwakamaru (Assassin) 2
# Utsumi Erice 3
# Utsumi Erice (Avenger) 4
# Valkyrie 5
# Van Gogh 6
# Vlad III 7
# Vlad III (EXTRA) 8
# Voyager 9
# Vritra 10
# Wandjina 11
# Watanabe-no-Tsuna 12
# William Shakespeare 13
# William Tell 14
# Wolfgang Amadeus Mozart 15
# Xiang Yu 16
# Xu Fu 17
# Xuanzang Sanzang 18
# Yagyu Munenori 19
# Yamanami Keisuke 20
# Yamato Takeru 21
# Yang Guifei 22
# Yu Mei-ren 23
# Yu Mei-ren (Lancer) 24
# Yui Shousetsu 25
# Zenobia 26
# Zhang Jue 27
# Zhuge Liang (El-Melloi II) 28
#                            Name      Class Star  \
# 0               Mash Kyrielight   Shielder    4
# 1      Mash Kyrielight(Ortinax)   Shielder    4
# 2              Abigail Williams  Foreigner    5
# 3     Abigail Williams (Summer)  Foreigner    5
# 4                      Achilles      Rider    5
# ..                          ...        ...  ...
# 414         Yu Mei-ren (Lancer)     Lancer    4
# 415               Yui Shousetsu     Caster    4
# 416                     Zenobia     Archer    4
# 417                   Zhang Jue     Caster    3
# 418  Zhuge Liang (El-Melloi II)     Caster    5
#
#                                                 Traits  \
# 0    Humanoid, Servant, Female, Riding, Heaven or E...
# 1    Humanoid, Servant, Female, Riding, Heaven or E...
# 2    [Female, Divine, Humanoid, Servant, Heaven or ...
# 3    [Servant, Humanoid, Female, Child, Divine, Thr...
# 4    [Humanoid, Servant, Male, Riding, Heaven or Ea...
# ..                                                 ...
# 414  [Humanoid, Servant, Female, Heaven or Earth, D...
# 415  [Servant, Humanoid, Female, Weak to Enuma Elis...
# 416  [Female, Lawful, Good, Servant, Humanoid, Weak...
# 417  [Servant, Humanoid, Hominidae, Male, Weak to E...
# 418  [Humanoid, Servant, Weak to Enuma Elish, Brynh...
#
#                                                   Tags  \
# 0    DEF Support, Damage Cut, Support, Target Focus...
# 1    DEF Support, Damage Cut, Support, Target Focus...
# 2    [NP Regen Support, NP Damage Support, Self NP ...
# 3    [Sleep, Buff Removal, DEF Down, Terror, Stun, ...
# 4    [Self Quick Up, Self Crit Damage Up, Self Invi...
# ..                                                 ...
# 414  [Self Guts, Self NP Gain Up, Field Bonus, NP G...
# 415  [Self Guts, Self HP Regen, Self Debuff Immune,...
# 416  [Self Arts Up, Self NP Regen, Star Regen, Self...
# 417  [Quick Support, Arts Support, Star Gather Rate...
# 418  [Crit Damage Support, NP Gauge Support, DEF Su...
#
#                  Skill 1 Base - Nome  \
# 0       Transient Wall of Snowflakes
# 1                      Bunker Bolt A
# 2                  Faithful Prayer C
# 3               The Rose's Slumber B
# 4                  Drómos Komḗtēs A+
# ..                               ...
# 414   Summer Incarnated Elemental A+
# 415  Counterfeit Life (Subspecies) C
# 416             Augusta Assumption B
# 417             General of Heaven B-
# 418                 Discerning Eye A
#
#                               Skill 1 Base - Descricao  \
# 0               Increase DEF for all allies (3 turns).
# 1    Increase own Buster Card effectiveness (1 time...
# 2    Increase NP Gauge for all allies by 10% each t...
# 3    Inflict Sleep on a single enemy (2 turns) [Sle...
# 4    Increase own Quick Card effectiveness (3 turns...
# ..                                                 ...
# 414  Apply Guts to self (1 time, 5 turns).Increase ...
# 415  Apply Guts to self (1 time, 5 turns).Apply to ...
# 416  Increase own Arts Card effectiveness (3 turns)...
# 417  Increase Quick Card effectiveness for all alli...
# 418  Increase Critical Strength for an ally (3 turn...
#
#            Skill 1 Upgrade - Nome  \
# 0    Honorable Wall of Snowflakes
# 1                  Black Barrel B
# 2            Light in the Abyss A
# 3                            None
# 4                            None
# ..                            ...
# 414                          None
# 415                          None
# 416                          None
# 417                          None
# 418                          None
#
#                            Skill 1 Upgrade - Descricao  \
# 0    Increase DEF for all allies (3 turns).Apply Da...
# 1    ncrease own Buster Card effectiveness (1 time,...
# 2    Increase NP Gauge for all allies by 10% each t...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 414                                               None
# 415                                               None
# 416                                               None
# 417                                               None
# 418                                               None
#
#                Skill 2 Base - Nome  ... Skill 2 Upgrade - Nome  \
# 0          Obscurant Wall of Chalk  ...                   none
# 1                   Amalgam Goad D  ...                   none
# 2                  Mass Hysteria B  ...                   None
# 3                 Mass Hysteria B+  ...     Midsummer Nights A
# 4             Andreíos Amárantos B  ...                   None
# ..                             ...  ...                    ...
# 414        Conqueror's Princess EX  ...                   None
# 415            Patriot's Tactics B  ...                   None
# 416  Aurelianus's Siege (Resist) A  ...                   None
# 417                Great Teacher A  ...                   None
# 418          Tactician's Advice A+  ...                   None
#
#                            Skill 2 Upgrade - Descricao  \
# 0                                                 none
# 1                                                 none
# 2                                                 None
# 3    Inflict Terror status on all enemies (3 turns)...
# 4                                                 None
# ..                                                 ...
# 414                                               None
# 415                                               None
# 416                                               None
# 417                                               None
# 418                                               None
#
#               Skill 3 Base - Nome  \
# 0    Shield of Rousing Resolution
# 1         Tragic Shield of Rousal
# 2                 Witch Trials A+
# 3               Those Who Guide A
# 4         Diatrekhōn Astēr Lonkhē
# ..                            ...
# 414       Dance of Bygone Days EX
# 415       Magecraft (Elements) B+
# 416            Glory to Palmyra A
# 417                Taipingjing EX
# 418        Tactician's Command A+
#
#                               Skill 3 Base - Descricao Skill 3 Upgrade - Nome  \
# 0    Apply Target Focus to self (1 turn).Increase o...                   none
# 1    Apply Invincible to self (1 turn).Apply Target...                   none
# 2    Decrease NP Gauge for a single enemy by 1.Decr...                   None
# 3    Increase own NP Gauge.Increase own Debuff Succ...                   None
# 4    Apply Target Focus to self (1 turn).Increase o...                   None
# ..                                                 ...                    ...
# 414  Increase own Quick Card effectiveness (3 turns...                   None
# 415  Increase Arts Card effectiveness for an ally (...                   None
# 416  Increase ATK for all allies (3 turns).Increase...                   None
# 417  Increase own NP Gauge.80% chance to apply [For...                   None
# 418  Increase ATK for all allies (3 turns).Apply Da...                   None
#
#     Skill 3 Upgrade - Descricao                      NP Base - Nome  \
# 0                          none                     Lord Chaldeas D
# 1                          none                    \tMold Camelot D
# 2                          None                    Qliphoth Rhizome
# 3                          None                          Dreamlands
# 4                          None                    Troias Tragōidia
# ..                          ...                                 ...
# 414                        None                    Anti-Fling Rondo
# 415                        None     Resshinjunmei - Fushakushinmyou
# 416                        None                   Authentic Triumph
# 417                        None  Cāngtiān Yǐ Sǐ, Huáng Tiān Dāng Lì
# 418                        None               Unreturning Formation
#
#                                    NP Base - Descricao  \
# 0    Apply Incoming Damage Cut for all allies (3 tu...
# 1    Apply Incoming Damage Cut for all allies (3 ti...
# 2    Remove buffs from a single enemy. (Activates f...
# 3    Remove defensive buffs from all enemies [Activ...
# 4    Deals damage to all enemies. Overcharge: Incre...
# ..                                                 ...
# 414  Deal damage to a single enemy.Deal extra speci...
# 415  Increase ATK for all allies with Quick buffs (...
# 416  Increase own ATK by 10% (1 turn) [Activates fi...
# 417  Decrease Quick Resist by 20% for all enemies w...
# 418  Decrease DEF for all enemies (3 turns).Inflict...
#
#                      NP Upgrade - Nome  \
# 0        Lord Camelot (Upgrade 1) B+++
# 1                                 none
# 2                                 None
# 3                                 None
# 4         Troias Tragōidia (Upgrade 1)
# ..                                 ...
# 414                               None
# 415                               None
# 416                               None
# 417                               None
# 418  Unreturning Formation (Upgrade 1)
#
#                                 NP Upgrade - Descricao
# 0    Apply Incoming Damage Cut for all allies (3 tu...
# 1                                                 none
# 2                                                 None
# 3                                                 None
# 4    Deals damage to all enemies.Inflict Confusion ...
# ..                                                 ...
# 414                                               None
# 415                                               None
# 416                                               None
# 417                                               None
# 418  Greatly decrease DEF for all enemies (3 turns)...
#
# [419 rows x 21 columns]
# Warning: Total number of columns (21) exceeds max_columns (20) limiting to first (20) columns.
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['Traits', 'Tags'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('Star').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Star')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Star', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_4['Star'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_4, x='index', y='Star', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
#lista_url_filtrado[0]
#df

# %% [markdown]
# Inserir manualmente:
#
# https://fgo.gamepress.gg/servant/melusine
#
# https://fgo.gamepress.gg/servant/nikola-tesla
#
# https://fgo.gamepress.gg/servant/ptolemy
#
# https://fgo.gamepress.gg/servant/space-ishtar
#
# https://fgo.gamepress.gg/servant/udk-barghest

# %%
#Remove se der erro
lista_url_filtrado = lista_url_filtrado[3:]

# %%
first_url = lista_url_filtrado[0]
response = requests.get(first_url)
soup = BeautifulSoup(response.content, 'html.parser')

#Nome
servant_div_1 = soup.find('div', id = 'page-title')
servant_h1 = servant_div_1.find('h1')
servant_name = servant_h1.get_text(strip=True)

servant_table_align_raw = soup.find('table', class_ = 'attri-align-table')

servant_attribute_raw = servant_table_align_raw.find_all('tr')[0].find('a')
servant_attribute = servant_attribute_raw.get_text(strip=True)

servant_alignment_raw = servant_table_align_raw.find_all('tr')[1].find('a')
servant_alignment = servant_alignment_raw.get_text(strip=True)

servant_id_raw = soup.find('table', class_ = 'assorted-info')
servant_id = servant_id_raw.find_all('tr')[0].find('td').get_text(strip=True)
servant_id

#print("ID: ", servant_id)
#print("Nome: ", servant_name)
#print("Attribute: ", servant_attribute)
#print("Alignment: ", servant_alignment)
# Out:
# '195'

# %%
df = pd.DataFrame(columns=["ID", "Nome", "Attribute", "Alignment"])

print(df)
# Out:
# Empty DataFrame
# Columns: [ID, Nome, Attribute, Alignment]
# Index: []

# %%
for url in lista_url_filtrado:
    #time.sleep(10)
    response = requests.get(url)

    soup = BeautifulSoup(response.content, 'html.parser')

    #Nome
    servant_div_1 = soup.find('div', id = 'page-title')
    servant_h1 = servant_div_1.find('h1')
    servant_name = servant_h1.get_text(strip=True)

    servant_table_align_raw = soup.find('table', class_ = 'attri-align-table')

    servant_attribute_raw = servant_table_align_raw.find_all('tr')[0].find('a')
    servant_attribute = servant_attribute_raw.get_text(strip=True)

    servant_alignment_raw = servant_table_align_raw.find_all('tr')[1].find('a')
    servant_alignment = servant_alignment_raw.get_text(strip=True)

    servant_id_raw = soup.find('table', class_ = 'assorted-info')
    servant_id = servant_id_raw.find_all('tr')[0].find('td').get_text(strip=True)

    df.loc[len(df.index)] = [servant_id, servant_name, servant_attribute, servant_alignment]

    df.to_csv('servants.csv')
